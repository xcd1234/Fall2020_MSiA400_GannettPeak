# %% [markdown]
# # Gannett Peak: Test Random Forest classifier model

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
from dataPrep import *

# %% [markdown]
# # Tune hyperparameters

# %%
def paramTune():
    dOb = dataPrep()
    # Number of trees in random forest
    n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
    # Number of features to consider at every split
    max_features = ['auto', None]
    # Maximum number of levels in tree
    max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
    max_depth.append(None)
    # Minimum number of samples required to split a node
    min_samples_split = [2, 5, 10]
    # Minimum number of samples required at each leaf node
    min_samples_leaf = [1, 2, 4]
    # Method of selecting samples for training each tree
    bootstrap = [True, False]
    # Create the random grid
    random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
    model = RandomForestClassifier()
    tuned = RandomizedSearchCV(estimator = model, 
                                   param_distributions = random_grid, 
                                   n_iter = 100, cv = 5, verbose=2, 
                                   random_state=42, 
                                   n_jobs = -1)
    X,y,Xtest,ytest = dOb.dataClass(0,False)
    tuned.fit(X,y)
    return tuned

# %%
tmodel = paramTune()
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=True
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=True
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=True
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=True
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=True
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=True
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=True
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=True
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=True
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=True
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, bootstrap=False
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, bootstrap=False
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, bootstrap=False
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, bootstrap=False
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, bootstrap=False
# [CV] n_estimators=1600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=10, bootstrap=True
# [CV] n_estimators=1600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=10, bootstrap=True
# [CV] n_estimators=1600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=10, bootstrap=True
# [CV] n_estimators=1600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=10, bootstrap=True
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=True, total= 2.1min
# [CV] n_estimators=1600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=10, bootstrap=True
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=True, total= 2.1min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=True, total= 2.3min
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=True, total= 2.2min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=True, total= 2.5min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, bootstrap=False, total= 4.2min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, bootstrap=False, total= 4.2min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=100, bootstrap=False
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, bootstrap=False, total= 4.2min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=100, bootstrap=False
# [CV]  n_estimators=1600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=10, bootstrap=True, total= 5.2min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=100, bootstrap=False
# [CV]  n_estimators=1600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=10, bootstrap=True, total= 5.5min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=100, bootstrap=False
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, bootstrap=False, total= 4.6min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=100, bootstrap=False
# [CV]  n_estimators=1600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=10, bootstrap=True, total= 5.4min
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=60, bootstrap=False
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, bootstrap=False, total= 4.7min
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=60, bootstrap=False
# [CV]  n_estimators=1600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=10, bootstrap=True, total= 5.6min
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=60, bootstrap=False
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False, total= 6.4min
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=60, bootstrap=False
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False, total= 6.5min
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=60, bootstrap=False
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False, total= 6.4min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, bootstrap=False
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False, total= 6.7min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, bootstrap=False
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False, total= 6.9min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, bootstrap=False
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=True, total= 7.1min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, bootstrap=False
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=True, total= 7.3min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, bootstrap=False
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=True, total= 7.6min
# [CV] n_estimators=1800, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=False
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=True, total= 7.6min
# [CV] n_estimators=1800, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=False
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=True, total= 7.7min
# [CV] n_estimators=1800, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=False
# [CV]  n_estimators=1600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=10, bootstrap=True, total= 6.8min
# [CV] n_estimators=1800, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=False
# [CV]  n_estimators=1800, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=False, total= 1.9min
# [CV] n_estimators=1800, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=False
# [CV]  n_estimators=1800, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=False, total= 2.0min
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, bootstrap=True
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, bootstrap=False, total= 3.1min
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, bootstrap=True
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, bootstrap=False, total= 3.2min
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, bootstrap=True
# [CV]  n_estimators=1800, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=False, total= 2.2min
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, bootstrap=True
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, bootstrap=False, total= 3.2min
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, bootstrap=True
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, bootstrap=False, total= 3.1min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=90, bootstrap=False
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, bootstrap=True, total=  50.4s
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=90, bootstrap=False
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, bootstrap=False, total= 3.2min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=90, bootstrap=False
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, bootstrap=True, total=  49.1s
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=90, bootstrap=False
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, bootstrap=True, total=  44.2s
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=90, bootstrap=False
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, bootstrap=True, total=  49.1s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False, total= 9.4min
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=False
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, bootstrap=True, total=  56.3s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False, total= 9.7min
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=False
# [CV]  n_estimators=1800, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=False, total= 2.9min
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False, total=10.3min
# [CV] n_estimators=1600, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False, total=10.9min
# [CV] n_estimators=1600, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False
# [CV]  n_estimators=1800, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=False, total= 3.0min
# [CV] n_estimators=1600, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=60, bootstrap=False, total= 7.8min
# [CV] n_estimators=1600, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=60, bootstrap=False, total= 8.1min
# [CV] n_estimators=1600, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=60, bootstrap=False, total= 7.6min
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=60, bootstrap=False, total= 8.4min
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=60, bootstrap=False, total= 8.2min
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False, total=10.0min
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=100, bootstrap=False, total=11.7min
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=100, bootstrap=False, total=11.8min
# [CV] n_estimators=1800, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, bootstrap=False
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=100, bootstrap=False, total=12.5min
# [CV] n_estimators=1800, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, bootstrap=False
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=100, bootstrap=False, total=12.1min
# [CV] n_estimators=1800, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, bootstrap=False
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=100, bootstrap=False, total=13.0min
# [CV] n_estimators=1800, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=90, bootstrap=False, total= 8.8min
# [CV] n_estimators=1800, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=90, bootstrap=False, total= 8.4min
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=70, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=90, bootstrap=False, total= 8.9min
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=70, bootstrap=False
# [CV]  n_estimators=1600, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False, total= 8.1min
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=70, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=90, bootstrap=False, total= 9.3min
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=70, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=90, bootstrap=False, total= 9.9min
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=70, bootstrap=False
# [CV]  n_estimators=1600, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False, total= 8.3min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1600, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False, total= 8.0min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1600, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False, total= 8.2min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=False, total=10.7min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1600, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=False, total= 8.7min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=False, total=10.6min
# [CV] n_estimators=1800, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=30, bootstrap=False, total= 8.6min
# [CV] n_estimators=1800, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, bootstrap=False
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=False, total=10.6min
# [CV] n_estimators=1800, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=70, bootstrap=False, total= 2.4min
# [CV] n_estimators=1800, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, bootstrap=False
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=False, total=10.5min
# [CV] n_estimators=1800, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=30, bootstrap=False, total= 8.4min
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=80, bootstrap=True
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=10, bootstrap=False, total=11.2min
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=80, bootstrap=True
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=70, bootstrap=False, total= 2.7min
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=80, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=30, bootstrap=False, total= 9.6min
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=80, bootstrap=True
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=70, bootstrap=False, total= 2.8min
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=80, bootstrap=True
# [CV]  n_estimators=1800, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, bootstrap=False, total= 4.8min
# [CV] n_estimators=1800, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=70, bootstrap=False, total= 3.1min
# [CV] n_estimators=1800, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=1800, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, bootstrap=False, total= 5.3min
# [CV] n_estimators=1800, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=30, bootstrap=False, total= 9.4min
# [CV] n_estimators=1800, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=1800, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, bootstrap=False, total= 5.7min
# [CV] n_estimators=1800, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=1800, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, bootstrap=False, total= 6.1min
# [CV] n_estimators=1600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=70, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=70, bootstrap=False, total= 3.4min
# [CV] n_estimators=1600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=70, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=80, bootstrap=True, total= 1.9min
# [CV] n_estimators=1600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=70, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=80, bootstrap=True, total= 1.6min
# [CV] n_estimators=1600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=70, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=80, bootstrap=True, total= 1.7min
# [CV] n_estimators=1600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=70, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=80, bootstrap=True, total= 1.5min
# [CV] n_estimators=1400, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=80, bootstrap=True
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=80, bootstrap=True, total= 1.7min
# [CV] n_estimators=1400, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=80, bootstrap=True
# [CV]  n_estimators=1800, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, bootstrap=False, total= 6.9min
# [CV] n_estimators=1400, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=80, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=30, bootstrap=False, total=10.3min
# [CV] n_estimators=1400, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=80, bootstrap=True
# [CV]  n_estimators=1800, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, bootstrap=False, total= 5.8min
# [CV] n_estimators=1400, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=80, bootstrap=True
# [CV]  n_estimators=1800, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, bootstrap=False, total= 5.8min
# [CV] n_estimators=1800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=20, bootstrap=True, total= 8.3min
# [CV] n_estimators=1800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True
# [CV]  n_estimators=1800, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, bootstrap=False, total= 5.7min
# [CV] n_estimators=1800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True
# [CV]  n_estimators=1800, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, bootstrap=False, total= 6.0min
# [CV] n_estimators=1800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True
# [CV]  n_estimators=1800, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, bootstrap=False, total= 5.9min
# [CV] n_estimators=1800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=20, bootstrap=True, total= 8.1min
# [CV] n_estimators=1400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=80, bootstrap=False
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=20, bootstrap=True, total= 8.0min
# [CV] n_estimators=1400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=80, bootstrap=False
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=20, bootstrap=True, total= 7.8min
# [CV] n_estimators=1400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=80, bootstrap=False
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=20, bootstrap=True, total= 8.1min
# [CV] n_estimators=1400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=80, bootstrap=False
# [CV]  n_estimators=1800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True, total= 3.1min
# [CV] n_estimators=1400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=80, bootstrap=False
# [CV]  n_estimators=1800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True, total= 2.9min
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=None, bootstrap=False
# [CV]  n_estimators=1800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True, total= 3.3min
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=None, bootstrap=False
# [CV]  n_estimators=1800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True, total= 3.4min
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=None, bootstrap=False
# [CV]  n_estimators=1800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True, total= 3.6min
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=None, bootstrap=False
# [CV]  n_estimators=1400, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=80, bootstrap=True, total=10.4min
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=None, bootstrap=False
# [CV]  n_estimators=1400, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=80, bootstrap=True, total=10.7min
# [CV] n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=40, bootstrap=False
# [CV]  n_estimators=1400, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=80, bootstrap=True, total=10.2min
# [CV] n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=40, bootstrap=False
# [CV]  n_estimators=1400, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=80, bootstrap=True, total=10.4min
# [CV] n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=40, bootstrap=False
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=None, bootstrap=False, total= 4.3min
# [CV] n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=40, bootstrap=False
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=None, bootstrap=False, total= 4.3min
# [CV] n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=40, bootstrap=False
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=None, bootstrap=False, total= 4.6min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=None, bootstrap=False, total= 4.3min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1400, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=80, bootstrap=True, total=10.2min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed: 42.5min
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=None, bootstrap=False, total= 4.6min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=40, bootstrap=False, total= 4.2min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=40, bootstrap=False, total= 3.8min
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False
# [CV]  n_estimators=1600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=70, bootstrap=False, total=17.8min
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False
# [CV]  n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=40, bootstrap=False, total= 4.3min
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False
# [CV]  n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=40, bootstrap=False, total= 4.0min
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False
# [CV]  n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=40, bootstrap=False, total= 4.2min
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False
# [CV]  n_estimators=1600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=70, bootstrap=False, total=18.8min
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1800, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=False, total=20.0min
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1800, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=False, total=20.7min
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=70, bootstrap=False, total=19.9min
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=70, bootstrap=False, total=19.8min
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1800, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=False, total=21.9min
# [CV] n_estimators=1200, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=20, bootstrap=False
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True, total= 7.4min
# [CV] n_estimators=1200, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=20, bootstrap=False
# [CV]  n_estimators=1800, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=False, total=22.3min
# [CV] n_estimators=1200, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=20, bootstrap=False
# [CV]  n_estimators=1800, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=30, bootstrap=False, total=21.7min
# [CV] n_estimators=1200, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=20, bootstrap=False
# [CV]  n_estimators=1600, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=70, bootstrap=False, total=21.6min
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True, total= 7.6min
# [CV] n_estimators=1200, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=20, bootstrap=False
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=50, bootstrap=False
# [CV]  n_estimators=1400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=80, bootstrap=False, total=16.8min
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=50, bootstrap=False
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True, total= 8.0min
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=50, bootstrap=False
# [CV]  n_estimators=1400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=80, bootstrap=False, total=18.2min
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=50, bootstrap=False
# [CV]  n_estimators=1400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=80, bootstrap=False, total=17.6min
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=50, bootstrap=False
# [CV]  n_estimators=1400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=80, bootstrap=False, total=18.9min
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True, total= 8.4min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=100, bootstrap=False
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=100, bootstrap=False
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True, total= 8.5min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=100, bootstrap=False
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False, total= 7.0min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=100, bootstrap=False
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False, total= 6.6min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=100, bootstrap=False
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False, total= 6.5min
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=50, bootstrap=True
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False, total= 6.9min
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=50, bootstrap=True
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False, total= 7.1min
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=50, bootstrap=True
# [CV]  n_estimators=1400, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=80, bootstrap=False, total=18.7min
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=50, bootstrap=True
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True, total= 9.0min
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=50, bootstrap=True
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True, total= 8.9min
# [CV] n_estimators=1800, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=90, bootstrap=True
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True, total= 9.5min
# [CV] n_estimators=1800, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=90, bootstrap=True
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True, total= 8.6min
# [CV] n_estimators=1800, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=90, bootstrap=True
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True, total= 8.7min
# [CV] n_estimators=1800, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=90, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=50, bootstrap=False, total= 9.6min
# [CV] n_estimators=1800, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=90, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=50, bootstrap=True, total= 4.8min
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=50, bootstrap=True, total= 5.1min
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=50, bootstrap=True, total= 5.1min
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=50, bootstrap=True, total= 5.0min
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=50, bootstrap=False, total= 9.3min
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=50, bootstrap=False, total=10.1min
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1200, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=20, bootstrap=False, total=11.1min
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1200, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=20, bootstrap=False, total=11.8min
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=50, bootstrap=False, total= 9.5min
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1200, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=20, bootstrap=False, total=11.7min
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1200, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=20, bootstrap=False, total=11.9min
# [CV]  n_estimators=1200, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=20, bootstrap=False, total=12.4min
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=100, bootstrap=True
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=100, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=50, bootstrap=False, total=10.0min
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=100, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=50, bootstrap=True, total= 5.8min
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=100, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=100, bootstrap=False, total=10.3min
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=100, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=100, bootstrap=False, total= 9.5min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=100, bootstrap=False, total=10.8min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=100, bootstrap=False, total= 9.6min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=100, bootstrap=True, total= 1.8min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=100, bootstrap=True, total= 1.9min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=100, bootstrap=False, total= 9.9min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=60, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=100, bootstrap=True, total= 1.9min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=60, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=100, bootstrap=True, total= 2.1min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=60, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True, total= 1.9min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=60, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=100, bootstrap=True, total= 2.0min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=60, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True, total= 2.0min
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=True
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=True, total=  14.1s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True, total= 1.7min
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True, total= 1.9min
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=True
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=True, total=  13.3s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, bootstrap=True, total= 1.8min
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=60, bootstrap=True
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=True, total=  12.5s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=60, bootstrap=True
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=True, total=  12.6s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=60, bootstrap=True
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=10, bootstrap=True, total=  11.4s
# ...
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=True
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=40, bootstrap=False, total= 6.9min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=True
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=100, bootstrap=True, total=18.0min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=True
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=100, bootstrap=True, total=17.9min
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=110, bootstrap=True
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=40, bootstrap=False, total= 6.9min
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=110, bootstrap=True
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=40, bootstrap=False, total= 7.5min
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=110, bootstrap=True
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=40, bootstrap=False, total= 8.6min
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=110, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=70, bootstrap=False, total=10.8min
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=110, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=70, bootstrap=False, total=10.6min
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=None, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=70, bootstrap=False, total=11.4min
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=None, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=70, bootstrap=False, total=10.9min
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=None, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=70, bootstrap=False, total=10.7min
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=None, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=100, bootstrap=True, total= 6.1min
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=None, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=100, bootstrap=True, total= 6.2min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=40, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=100, bootstrap=True, total= 6.3min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=40, bootstrap=True
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=True, total= 4.2min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=40, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=100, bootstrap=True, total= 6.6min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=40, bootstrap=True
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=True, total= 3.9min
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=40, bootstrap=True
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=True, total= 4.1min
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=40, bootstrap=True
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=True, total= 4.0min
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=40, bootstrap=True
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=2, max_features=None, max_depth=10, bootstrap=True, total= 3.9min
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=40, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=4, max_features=None, max_depth=100, bootstrap=True, total= 6.7min
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=40, bootstrap=True
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=110, bootstrap=True, total= 4.6min
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=40, bootstrap=True
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=110, bootstrap=True, total= 4.6min
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=110, bootstrap=True, total= 4.9min
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=40, bootstrap=True, total= 1.1min
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=110, bootstrap=True, total= 4.9min
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=40, bootstrap=True, total= 1.3min
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=None, max_depth=110, bootstrap=True, total= 5.0min
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=40, bootstrap=True, total= 1.3min
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=False
# [CV]  n_estimators=1600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=80, bootstrap=True, total=11.8min
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=False
# [CV]  n_estimators=1600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=80, bootstrap=True, total=11.8min
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=False
# [CV]  n_estimators=1600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=80, bootstrap=True, total=11.9min
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=40, bootstrap=True, total= 1.7min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=10, bootstrap=False
# [CV]  n_estimators=1600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=80, bootstrap=True, total=12.1min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=10, bootstrap=False
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=40, bootstrap=True, total= 1.8min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=10, bootstrap=False
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=False, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=10, bootstrap=False
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=False, total= 1.3min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=10, bootstrap=False
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=False, total= 1.1min
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=False, total= 1.1min
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=False, total= 1.2min
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=10, bootstrap=False, total= 1.3min
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False, total=  29.7s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False, total=  33.8s
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False, total=  30.3s
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=10, bootstrap=False, total= 1.2min
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=10, bootstrap=False, total= 1.4min
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False, total=  42.3s
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=10, bootstrap=False, total= 1.4min
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=True
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=100, bootstrap=False, total=  33.8s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=True
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=10, bootstrap=False, total= 1.5min
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=40, bootstrap=True, total= 6.7min
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=True
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=40, bootstrap=True, total= 7.1min
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=True
# [CV]  n_estimators=1600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=80, bootstrap=True, total=13.4min
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=40, bootstrap=True, total= 7.2min
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=40, bootstrap=True, total= 7.3min
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=1, max_features=None, max_depth=40, bootstrap=True, total= 7.2min
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False, total= 6.8min
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False, total= 6.7min
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False, total= 6.6min
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False, total= 6.7min
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=4, max_features=None, max_depth=30, bootstrap=False, total= 7.4min
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=True, total= 3.0min
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=True, total= 3.5min
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=True, total= 3.4min
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=True, total= 3.4min
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=40, bootstrap=True, total= 3.3min
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True, total= 9.3min
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True, total= 9.8min
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True, total= 9.8min
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True, total= 9.7min
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=2, max_features=None, max_depth=20, bootstrap=True, total= 9.5min
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=None, bootstrap=False, total=18.8min
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=None, bootstrap=False, total=19.8min
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=None, bootstrap=False, total=19.4min
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=None, bootstrap=False, total=19.3min
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=4, max_features=None, max_depth=None, bootstrap=False, total=20.8min
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed: 166.8min finished

# %%
tmodel.best_params_
# Out:
# {'n_estimators': 1000,
#  'min_samples_split': 10,
#  'min_samples_leaf': 2,
#  'max_features': None,
#  'max_depth': 10,
#  'bootstrap': True}

# %%
model = RandomForestClassifier(n_estimators=1000,
                                    min_samples_split=10,
                                    min_samples_leaf=2,
                                    max_features = None,
                                    max_depth = 10,
                                    bootstrap = True)

# %% [markdown]
# # Determine which lagging period performs the best

# %%
def trainLags(i):
    dOb = dataPrep()
    #for i in range(6):
    X,y,Xtest,ytest,Xval,yVal = dOb.dataClass(i,True)
    model = RandomForestClassifier(n_estimators=1000,
                                          min_samples_split=10,
                                          min_samples_leaf=2,
                                          max_features = None,
                                          max_depth = 10,
                                          bootstrap = True)
    model.fit(X, y)
    y_pred=model.predict(Xval)
    print(confusion_matrix(yVal, y_pred))
    print(model.score(Xval, yVal))

# %%
trainLags(0)
# Out:
# [[ 750 3827]
#  [1096 4666]]
# 0.5238417641938292

# %%
trainLags(1)
# Out:
# [[ 787 3478]
#  [1232 4529]]
# 0.5302214242968283

# %%
trainLags(2)
# Out:
# [[ 840 3525]
#  [ 694 4827]]
# 0.5732348776046935

# %%
trainLags(3)
# Out:
# [[1115 2976]
#  [1121 4629]]
# 0.5836805202723301

# %%
trainLags(4)
# Out:
# [[1117 3205]
#  [1214 4321]]
# 0.5516891549152886

# %%
trainLags(5)
# Out:
# [[1453 2741]
#  [ 562 4998]]
# 0.6613696944843142

# %% [markdown]
# ### Lag of 5 months performs best on validation data, with lag of 2 months and 3 months also performing better than 55%, which is the average number of positives that we have in the training data.

# %% [markdown]
# # Model with complete data

# %%
dOb = dataPrep()

# %%
X,y,Xtest,ytest,Xval,yVal = dOb.dataClass(2,True)
model = RandomForestClassifier(n_estimators=1000,
                                    min_samples_split=10,
                                    min_samples_leaf=2,
                                    max_features = None,
                                    max_depth = 10,
                                    bootstrap = True)
model.fit(X, y)
y_pred=model.predict(Xval)
print(confusion_matrix(yVal, y_pred))
print(model.score(Xval, yVal))
# Out:
# [[ 854 3511]
#  [ 712 4809]]
# 0.5728302650212421

# %% [markdown]
# # Model excluding Salary, Important Roles, Intern Roles

# %%
X,y,Xtest,ytest,Xval,yVal = dOb.dataClass(2,True)
X.drop('SalaryChange', axis=1)
X.drop('weight_Important',axis=1)
X.drop('weight_Intern',axis=1)
Xval.drop('SalaryChange', axis=1)
Xval.drop('weight_Important',axis=1)
Xval.drop('weight_Intern',axis=1)
Xtest.drop('SalaryChange', axis=1)
Xtest.drop('weight_Important',axis=1)
Xtest.drop('weight_Intern',axis=1)
model = RandomForestClassifier(n_estimators=1000,
                                    min_samples_split=10,
                                    min_samples_leaf=2,
                                    max_features = None,
                                    max_depth = 10,
                                    bootstrap = True)
model.fit(X, y)
y_pred=model.predict(Xval)
print(confusion_matrix(yVal, y_pred))
print(model.score(Xval, yVal))
# Out:
# [[ 841 3524]
#  [ 722 4799]]
# 0.5705037426663969

# %% [markdown]
# ### Comparing the two models for Cary, since salary and role data are not part of their competitors' data. However, the two models performed very similarly on the validation data.

# %% [markdown]
# ### Note: We proceeded with a lag of 2 months based on the Vector Auto Regression model's performance
