# %% [markdown]
# This code is similar to the Trading Strategy Simulation file, except the weight allocation strategy used here is CAPM tangency portfolio weight optimization.

# %%
import pandas as pd
import numpy as np

# %%
stock_df = pd.read_csv('yfinanceAPI_monthly3.csv')
stock_df = stock_df[['ticker', 'date2', 'monthly_return']]
stock_df.columns = ['Ticker', 'Date', 'Monthly_return']
stock_df
# Out:
#        Ticker     Date  Monthly_return
# 0           A  2016-01       -9.949780
# 1           A  2016-02       -0.796819
# 2           A  2016-03        6.693440
# 3           A  2016-04        2.982247
# 4           A  2016-05       12.145643
# ...       ...      ...             ...
# 138419   ZVLO  2019-09        0.000000
# 138420   ZVLO  2019-10        0.000000
# 138421   ZVLO  2019-11        0.000000
# 138422   ZVLO  2019-12        0.000000
# 138423   ZVLO  2020-01       19.999996
#
# [138424 rows x 3 columns]

# %%
stock_returns_grouped = stock_df.groupby(['Ticker'])
stock_returns_list = list(stock_returns_grouped)
stock_returns = {}
for i in stock_returns_list:
    stock_returns[i[0]] = i[1]
stock_returns
# Out:
# {'A':    Ticker     Date  Monthly_return
#  0       A  2016-01       -9.949780
#  1       A  2016-02       -0.796819
#  2       A  2016-03        6.693440
#  3       A  2016-04        2.982247
#  4       A  2016-05       12.145643
#  5       A  2016-06       -3.079331
#  6       A  2016-07        8.453566
#  7       A  2016-08       -2.348822
#  8       A  2016-09        0.483155
#  9       A  2016-10       -7.475033
#  10      A  2016-11        0.941002
#  11      A  2016-12        3.892492
#  12      A  2017-01        7.484643
#  13      A  2017-02        4.758028
#  14      A  2017-03        3.316183
#  15      A  2017-04        4.123317
#  16      A  2017-05        9.609465
#  17      A  2017-06       -1.488077
#  18      A  2017-07        0.809305
#  19      A  2017-08        8.245527
#  20      A  2017-09       -0.803485
#  21      A  2017-10        6.184058
#  22      A  2017-11        1.778613
#  23      A  2017-12       -3.064274
#  24      A  2018-01        9.646091
#  25      A  2018-02       -6.591323
#  26      A  2018-03       -2.463910
#  27      A  2018-04       -1.514579
#  28      A  2018-05       -5.810779
#  29      A  2018-06       -0.129190
#  30      A  2018-07        7.049661
#  31      A  2018-08        2.271345
#  32      A  2018-09        4.441813
#  33      A  2018-10       -7.956986
#  34      A  2018-11       11.668456
#  35      A  2018-12       -6.528223
#  36      A  2019-01       12.733487
#  37      A  2019-02        4.457585
#  38      A  2019-03        1.183287
#  39      A  2019-04       -2.139213
#  40      A  2019-05      -14.585991
#  41      A  2019-06       11.364629
#  42      A  2019-07       -6.839704
#  43      A  2019-08        2.449226
#  44      A  2019-09        7.994458
#  45      A  2019-10       -1.148372
#  46      A  2019-11        6.627057
#  47      A  2019-12        5.843938
#  48      A  2020-01       -1.090148,
#  'AA':    Ticker     Date  Monthly_return
#  49     AA  2016-01      -26.139813
#  50     AA  2016-02       23.026092
#  51     AA  2016-03        7.278849
#  52     AA  2016-04       16.597067
#  53     AA  2016-05      -16.768598
#  54     AA  2016-06        0.000000
#  55     AA  2016-07       14.563105
#  56     AA  2016-08       -4.808017
#  57     AA  2016-09        0.595238
#  695   ABBV  2018-03      -18.285403
#  696   ABBV  2018-04        3.063980
#  697   ABBV  2018-05        2.475419
#  698   ABBV  2018-06       -6.357396
#  699   ABBV  2018-07        0.563332
#  700   ABBV  2018-08        4.065910
#  701   ABBV  2018-09       -1.458623
#  702   ABBV  2018-10      -16.808209
#  703   ABBV  2018-11       21.091839
#  704   ABBV  2018-12       -2.206411
#  705   ABBV  2019-01      -11.839941
#  706   ABBV  2019-02       -1.307756
#  707   ABBV  2019-03        1.703662
#  708   ABBV  2019-04       -0.182848
#  709   ABBV  2019-05       -3.375742
#  710   ABBV  2019-06       -5.201407
#  711   ABBV  2019-07       -6.991371
#  712   ABBV  2019-08       -1.320934
#  713   ABBV  2019-09       15.181031
#  714   ABBV  2019-10        8.161843
#  715   ABBV  2019-11       10.282832
#  716   ABBV  2019-12        0.923295
#  717   ABBV  2020-01       -6.387075,
#  'ABC':     Ticker     Date  Monthly_return
#  718    ABC  2016-01      -13.643820
#  719    ABC  2016-02       -2.905391
#  720    ABC  2016-03       -0.080816
#  721    ABC  2016-04       -1.675339
#  722    ABC  2016-05      -11.491445
#  723    ABC  2016-06        5.788189
#  724    ABC  2016-07        7.400411
#  725    ABC  2016-08        2.481209
#  726    ABC  2016-09       -7.117379
#  727    ABC  2016-10      -12.948751
#  728    ABC  2016-11       11.423005
#  729    ABC  2016-12        0.256443
#  730    ABC  2017-01       11.625535
#  731    ABC  2017-02        5.267850
#  732    ABC  2017-03       -3.289251
#  733    ABC  2017-04       -7.288114
#  734    ABC  2017-05       12.321573
#  735    ABC  2017-06        3.007506
#  736    ABC  2017-07       -0.751071
#  737    ABC  2017-08      -14.071986
#  738    ABC  2017-09        3.115280
#  739    ABC  2017-10       -7.009072
#  740    ABC  2017-11       10.751478
#  741    ABC  2017-12        8.252741
#  742    ABC  2018-01        8.549360
#  743    ABC  2018-02       -4.151752
#  744    ABC  2018-03       -9.405213
#  745    ABC  2018-04        5.069002
#  746    ABC  2018-05       -8.920219
#  747    ABC  2018-06        3.810557
#  748    ABC  2018-07       -4.034242
#  749    ABC  2018-08       10.430799
#  750    ABC  2018-09        2.500839
#  751    ABC  2018-10       -4.576004
#  752    ABC  2018-11        1.478029
#  753    ABC  2018-12      -16.310458
#  754    ABC  2019-01       12.056455
#  755    ABC  2019-02        0.380487
#  756    ABC  2019-03       -4.537834
#  757    ABC  2019-04       -5.985905
#  758    ABC  2019-05        4.686299
#  759    ABC  2019-06        9.504240
#  760    ABC  2019-07        2.216741
#  761    ABC  2019-08       -5.158270
#  762    ABC  2019-09        0.072932
#  763    ABC  2019-10        3.704600
#  764    ABC  2019-11        3.443649
#  765    ABC  2019-12       -3.287463
#  766    ABC  2020-01        4.540113,
#  'ABCB':     Ticker     Date  Monthly_return
#  767   ABCB  2016-01      -14.886730
#  768   ABCB  2016-02       -6.705838
#  769   ABCB  2016-03        9.786935
#  770   ABCB  2016-04        6.152810
#  771   ABCB  2016-05        1.369429
#  772   ABCB  2016-06       -6.524583
#  928    ABG  2018-04       -0.666662
#  929    ABG  2018-05        3.728561
#  930    ABG  2018-06       -1.437814
#  931    ABG  2018-07        2.552881
#  932    ABG  2018-08        5.974391
#  933    ABG  2018-09       -7.718121
#  934    ABG  2018-10       -5.309093
#  935    ABG  2018-11        6.175122
#  936    ABG  2018-12       -3.559026
#  937    ABG  2019-01        5.985595
#  938    ABG  2019-02        1.613587
#  939    ABG  2019-03       -3.384873
#  940    ABG  2019-04       15.599769
#  941    ABG  2019-05       -7.470688
#  942    ABG  2019-06       13.681080
#  943    ABG  2019-07        9.177147
#  944    ABG  2019-08        2.410948
#  945    ABG  2019-09        8.515375
#  946    ABG  2019-10        0.781780
#  947    ABG  2019-11        7.476000
#  948    ABG  2019-12        0.857095
#  949    ABG  2020-01      -11.056446,
#  'ABM':     Ticker     Date  Monthly_return
#  950    ABM  2016-01        6.112223
#  951    ABM  2016-02        4.562100
#  952    ABM  2016-03        2.898097
#  953    ABM  2016-04        0.085504
#  954    ABM  2016-05        6.216983
#  955    ABM  2016-06        6.760328
#  956    ABM  2016-07        2.466451
#  957    ABM  2016-08        3.278678
#  958    ABM  2016-09        3.304739
#  959    ABM  2016-10       -1.154401
#  960    ABM  2016-11       12.589578
#  961    ABM  2016-12       -7.181848
#  962    ABM  2017-01       -0.688444
#  963    ABM  2017-02        0.990348
#  964    ABM  2017-03        6.888953
#  965    ABM  2017-04       -0.541988
#  966    ABM  2017-05       -0.347293
#  967    ABM  2017-06       -3.531602
#  968    ABM  2017-07        7.908078
#  969    ABM  2017-08       -0.425793
#  970    ABM  2017-09       -6.121979
#  971    ABM  2017-10        1.024308
#  972    ABM  2017-11        1.977620
#  973    ABM  2017-12      -11.869151
#  974    ABM  2018-01        1.291391
#  975    ABM  2018-02       -7.546668
#  976    ABM  2018-03       -4.778158
#  977    ABM  2018-04       -6.530558
#  978    ABM  2018-05       -8.576926
#  979    ABM  2018-06        2.529865
#  980    ABM  2018-07        7.559309
#  981    ABM  2018-08        1.666667
#  982    ABM  2018-09        1.670883
#  983    ABM  2018-10       -4.133846
#  984    ABM  2018-11        3.024384
#  985    ABM  2018-12        1.357331
#  986    ABM  2019-01        7.077982
#  987    ABM  2019-02        4.299510
#  988    ABM  2019-03        1.934930
#  989    ABM  2019-04        4.962100
#  990    ABM  2019-05       -4.529885
#  991    ABM  2019-06       10.344828
#  992    ABM  2019-07        5.702101
#  993    ABM  2019-08      -11.475428
#  994    ABM  2019-09       -2.522805
#  995    ABM  2019-10        0.892456
#  996    ABM  2019-11        4.196405
#  997    ABM  2019-12       -0.256131
#  998    ABM  2020-01        3.102630,
#  'ABMC':      Ticker     Date  Monthly_return
#  999    ABMC  2016-01      -15.384613
#  1000   ABMC  2016-02       -9.090907
#  1001   ABMC  2016-03       29.999993
#  1002   ABMC  2016-04       -7.692306
#  1003   ABMC  2016-05        0.000000
#  1004   ABMC  2016-06       16.666670
#  1005   ABMC  2016-07      -14.285717
#  1006   ABMC  2016-08       33.333333
#  1007   ABMC  2016-09      -18.750001
#  1008   ABMC  2016-10        0.000000
#  1009   ABMC  2016-11      -15.384613
#  1010   ABMC  2016-12        0.000000
#  1011   ABMC  2017-01        0.000000
#  1012   ABMC  2017-02        0.000000
#  1013   ABMC  2017-03        0.000000
#  1014   ABMC  2017-04        9.090907
#  1015   ABMC  2017-05      -16.666664
#  1016   ABMC  2017-06        0.000000
#  1017   ABMC  2017-07        0.000000
#  1018   ABMC  2017-08       29.999993
#  1019   ABMC  2017-09       -7.692306
#  1020   ABMC  2017-10        0.000000
#  1021   ABMC  2017-11      -16.666664
#  1022   ABMC  2017-12        0.000000
#  1023   ABMC  2018-01       39.999999
#  1024   ABMC  2018-02      -21.428572
#  1025   ABMC  2018-03        0.000000
#  1026   ABMC  2018-04       -9.090907
#  1027   ABMC  2018-05       -9.999998
#  1028   ABMC  2018-06        0.000000
#  1029   ABMC  2018-07        0.000000
#  1030   ABMC  2018-08        0.000000
#  1031   ABMC  2018-09        0.000000
#  1032   ABMC  2018-10        0.000000
#  1033   ABMC  2018-11       22.222217
#  1034   ABMC  2018-12      -36.363636
#  1035   ABMC  2019-01       28.571433
#  1036   ABMC  2019-02      -22.222225
#  1037   ABMC  2019-03       14.285711
#  1038   ABMC  2019-04      -12.499998
#  1039   ABMC  2019-05       28.571433
#  1040   ABMC  2019-06      -22.222225
#  1041   ABMC  2019-07        0.000000
#  1042   ABMC  2019-08        0.000000
#  1043   ABMC  2019-09        0.000000
#  1044   ABMC  2019-10        0.000000
#  1045   ABMC  2019-11        0.000000
#  1046   ABMC  2019-12        0.000000
#  1047   ABMC  2020-01        0.000000,
#  'ABMD':      Ticker     Date  Monthly_return
#  1048   ABMD  2016-01       -5.482939
#  1049   ABMD  2016-02       -6.234618
#  1050   ABMD  2016-03       18.497682
#  1051   ABMD  2016-04        2.457549
#  1052   ABMD  2016-05        2.233887
#  1053   ABMD  2016-06       10.049344
#  1054   ABMD  2016-07        7.942172
#  1055   ABMD  2016-08       -0.025429
#  1056   ABMD  2016-09        9.021536
#  1057   ABMD  2016-10      -18.346557
#  1058   ABMD  2016-11        6.905420
#  1059   ABMD  2016-12        0.392019
#  1060   ABMD  2017-01       -5.599927
#  1061   ABMD  2017-02       10.905329
#  1062   ABMD  2017-03        6.128673
#  1063   ABMD  2017-04        4.089465
#  1064   ABMD  2017-05        5.455790
#  1065   ABMD  2017-06        4.271273
#  1066   ABMD  2017-07        3.342633
#  1067   ABMD  2017-08        1.829973
#  1068   ABMD  2017-09       11.803715
#  1069   ABMD  2017-10       14.424669
#  1070   ABMD  2017-11        0.995230
#  1071   ABMD  2017-12       -3.813382
#  1072   ABMD  2018-01       25.393520
#  1073   ABMD  2018-02       14.119146
#  1074   ABMD  2018-03        8.505481
#  1075   ABMD  2018-04        3.422806
#  1076   ABMD  2018-05       26.645622
#  1077   ABMD  2018-06        7.322761
#  1078   ABMD  2018-07      -13.328442
#  1079   ABMD  2018-08       14.681406
#  1080   ABMD  2018-09       10.617840
#  1081   ABMD  2018-10      -24.135628
#  1082   ABMD  2018-11       -2.497075
#  1083   ABMD  2018-12       -2.296496
#  1084   ABMD  2019-01        8.008245
#  1085   ABMD  2019-02       -4.719858
#  1086   ABMD  2019-03      -14.621825
#  1087   ABMD  2019-04       -2.864243
#  1088   ABMD  2019-05       -5.583789
#  1089   ABMD  2019-06       -0.545977
#  1090   ABMD  2019-07        6.936930
#  1091   ABMD  2019-08      -30.689974
#  1092   ABMD  2019-09       -7.862437
#  1093   ABMD  2019-10       16.690091
#  1094   ABMD  2019-11       -5.491863
#  1095   ABMD  2019-12      -13.044142
#  1096   ABMD  2020-01        9.531631,
#  'ABT':      Ticker     Date  Monthly_return
#  1097    ABT  2016-01      -15.188452
#  1098    ABT  2016-02        2.351360
#  1099    ABT  2016-03        7.976285
#  1100    ABT  2016-04       -6.436472
#  1101    ABT  2016-05        1.876626
#  1102    ABT  2016-06       -0.807457
#  1103    ABT  2016-07       14.539923
#  1104    ABT  2016-08       -6.100550
#  1105    ABT  2016-09        0.642530
#  1106    ABT  2016-10       -6.622238
#  1107    ABT  2016-11       -2.981653
#  1108    ABT  2016-12        0.893083
#  1109    ABT  2017-01        9.450166
#  1110    ABT  2017-02        7.924358
#  1111    ABT  2017-03       -1.486242
#  1112    ABT  2017-04       -1.132800
#  1113    ABT  2017-05        4.628794
#  1114    ABT  2017-06        6.460792
#  1115    ABT  2017-07        1.732489
#  1116    ABT  2017-08        3.578697
#  1117    ABT  2017-09        4.750682
#  1118    ABT  2017-10        2.127555
#  1119    ABT  2017-11        3.946175
#  1120    ABT  2017-12        1.241794
#  1121    ABT  2018-01        9.439745
#  1122    ABT  2018-02       -2.944013
#  1123    ABT  2018-03       -0.679594
#  1124    ABT  2018-04       -2.520352
#  1125    ABT  2018-05        5.848957
#  1126    ABT  2018-06       -0.877616
#  1127    ABT  2018-07        7.943287
#  1128    ABT  2018-08        1.983510
#  1129    ABT  2018-09        9.754645
#  1130    ABT  2018-10       -5.638697
#  1131    ABT  2018-11        7.412247
#  1132    ABT  2018-12       -2.322758
#  1133    ABT  2019-01        1.366526
#  1134    ABT  2019-02        6.357923
#  1135    ABT  2019-03        2.988913
#  1136    ABT  2019-04       -0.068069
#  1137    ABT  2019-05       -4.311202
#  1138    ABT  2019-06       10.468948
#  1139    ABT  2019-07        3.955014
#  1140    ABT  2019-08       -2.043621
#  1141    ABT  2019-09       -1.933887
#  1142    ABT  2019-10        0.328899
#  1143    ABT  2019-11        2.200701
#  1144    ABT  2019-12        1.650078
#  1145    ABT  2020-01        3.083918,
#  'ABTX':      Ticker     Date  Monthly_return
#  1146   ABTX  2016-01      -21.564475
#  1147   ABTX  2016-02       -6.954183
#  1148   ABTX  2016-03        6.431075
#  1149   ABTX  2016-04       14.588974
#  1150   ABTX  2016-05       13.444192
#  1151   ABTX  2016-06        4.187602
#  1152   ABTX  2016-07        1.527336
#  1153   ABTX  2016-08        3.919240
#  1154   ABTX  2016-09        2.857147
#  1155   ABTX  2016-10       -2.407408
#  1156   ABTX  2016-11       16.129024
#  46600     FC  2020-01       -1.830593,
#  'FCAP':       Ticker     Date  Monthly_return
#  46601   FCAP  2016-01       -7.164751
#  46602   FCAP  2016-02        9.368554
#  46603   FCAP  2016-03        4.559707
#  46604   FCAP  2016-04        4.727308
#  46605   FCAP  2016-05        9.548612
#  46606   FCAP  2016-06        8.135646
#  46607   FCAP  2016-07       -4.101497
#  46608   FCAP  2016-08       -5.846170
#  46609   FCAP  2016-09        4.614645
#  46610   FCAP  2016-10       -1.605271
#  46611   FCAP  2016-11       -3.071047
#  46612   FCAP  2016-12        7.738503
#  46613   FCAP  2017-01        1.480569
#  46614   FCAP  2017-02       -0.395139
#  46615   FCAP  2017-03        3.627800
#  46616   FCAP  2017-04       -5.185186
#  46617   FCAP  2017-05       -0.625021
#  46618   FCAP  2017-06       -1.352089
#  46619   FCAP  2017-07       -0.770461
#  46620   FCAP  2017-08        3.849877
#  46621   FCAP  2017-09       11.253405
#  46622   FCAP  2017-10        1.408441
#  46623   FCAP  2017-11       -1.805554
#  46624   FCAP  2017-12        4.573863
#  46625   FCAP  2018-01        1.741963
#  46626   FCAP  2018-02       -0.133769
#  46627   FCAP  2018-03        7.816893
#  46628   FCAP  2018-04       -4.750007
#  46629   FCAP  2018-05       -2.624682
#  46630   FCAP  2018-06       12.695173
#  46631   FCAP  2018-07       -8.375456
#  46632   FCAP  2018-08        5.227214
#  46633   FCAP  2018-09       -3.748243
#  46634   FCAP  2018-10       14.662154
#  46635   FCAP  2018-11      -14.220717
#  46636   FCAP  2018-12       13.369769
#  46637   FCAP  2019-01        5.367225
#  46638   FCAP  2019-02       11.706879
#  46639   FCAP  2019-03        3.448947
#  46640   FCAP  2019-04       -0.640780
#  46641   FCAP  2019-05       -4.729338
#  46642   FCAP  2019-06        4.189194
#  46643   FCAP  2019-07       12.287291
#  46644   FCAP  2019-08       -0.264317
#  46645   FCAP  2019-09        2.605705
#  46646   FCAP  2019-10        1.504401
#  46647   FCAP  2019-11       15.758092
#  46648   FCAP  2019-12        7.845931
#  46649   FCAP  2020-01       -4.835609,
#  ...}

# %%
risk_free = pd.read_csv('TB3MS.csv')
risk_free
# Out:
#        Date  Risk Free Return
# 0   2016-01              0.02
# 1   2016-02              0.03
# 2   2016-03              0.02
# 3   2016-04              0.02
# 4   2016-05              0.02
# 5   2016-06              0.02
# 6   2016-07              0.03
# 7   2016-08              0.03
# 8   2016-09              0.02
# 9   2016-10              0.03
# 10  2016-11              0.04
# 11  2016-12              0.04
# 12  2017-01              0.04
# 13  2017-02              0.04
# 14  2017-03              0.06
# 15  2017-04              0.07
# 16  2017-05              0.07
# 17  2017-06              0.08
# 18  2017-07              0.09
# 19  2017-08              0.08
# 20  2017-09              0.09
# 21  2017-10              0.09
# 22  2017-11              0.10
# 23  2017-12              0.11
# 24  2018-01              0.12
# 25  2018-02              0.13
# 26  2018-03              0.14
# 27  2018-04              0.15
# 28  2018-05              0.16
# 29  2018-06              0.16
# 30  2018-07              0.16
# 31  2018-08              0.17
# 32  2018-09              0.18
# 33  2018-10              0.19
# 34  2018-11              0.19
# 35  2018-12              0.20
# 36  2019-01              0.20
# 37  2019-02              0.20
# 38  2019-03              0.20
# 39  2019-04              0.20
# 40  2019-05              0.20
# 41  2019-06              0.18
# 42  2019-07              0.18
# 43  2019-08              0.16
# 44  2019-09              0.16
# 45  2019-10              0.14
# 46  2019-11              0.13
# 47  2019-12              0.13
# 48  2020-01              0.13

# %%
dow_df = pd.read_csv('DOW30.csv')
dow = list(dow_df['Ticker'])
dow
# Out:
# ['MSFT',
#  'INTC',
#  'KO',
#  'AAPL',
#  'PG',
#  'HD',
#  'IBM',
#  'HON',
#  'NKE',
#  'V',
#  'CVX',
#  'BA',
#  'CAT',
#  'VZ',
#  'MCD',
#  'GS',
#  'JPM',
#  'MMM',
#  'TRV',
#  'CSCO',
#  'MRK',
#  'JNJ',
#  'AXP',
#  'DOW',
#  'AMGN',
#  'DIS',
#  'WMT',
#  'UNH',
#  'CRM',
#  'WBA']

# %%
classification_df = pd.read_csv('RF_Prediction.csv')
classification_df
# Out:
#      Ticker  2019-08  2019-09  2019-10  2019-11  2019-12  2020-01
# 0         A        1        1        1        1        1        1
# 1        AA        1        1        1        1        1        0
# 2       AAL        1        1        1        1        1        1
# 3       AAN        1        1        1        1        1        1
# 4      AAOI        1        0        0        0        1        0
# ...     ...      ...      ...      ...      ...      ...      ...
# 2206   ZNGA        1        1        1        1        1        1
# 2207    ZOM        0        0        0        1        0        0
# 2208   ZSAN        0        0        0        0        0        0
# 2209    ZTS        1        1        1        1        1        1
# 2210   ZUMZ        1        1        1        1        1        1
#
# [2211 rows x 7 columns]

# %%
months = list(classification_df.columns)[1:]
months
# Out:
# ['2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2020-01']

# %%
positives = {}
for month in months:
    positives[month] = list(classification_df['Ticker'][classification_df[month] == 1])
positives
# Out:
# {'2019-08': ['A',
#   'AA',
#   'AAL',
#   'AAN',
#   'AAOI',
#   'AAP',
#   'AAPL',
#   'AAWW',
#   'AB',
#   'ABBV',
#   'ABC',
#   'ABCB',
#   'ABG',
#   'ABM',
#   'ABMD',
#   'ABT',
#   'ACAD',
#   'ACC',
#   'ACCO',
#   'ACHC',
#   'ACIA',
#   'ACN',
#   'ACNB',
#   'ACOR',
#   'ADBE',
#   'ADDDF',
#   'ADI',
#   'ADM',
#   'ADP',
#   'ADRO',
#   'ADS',
#   'ADSK',
#   'ADSW',
#   'ADT',
#   'ADTN',
#   'ADUS',
#   'AEE',
#   'AEIS',
#   'AEO',
#   'AEP',
#   'AES',
#   'AFI',
#   'AFL',
#   'AGCO',
#   'AGIO',
#   'AGO',
#   'AGR',
#   'AIMC',
#   'AIN',
#   'AIR',
#   'AIRI',
#   'AIT',
#   'AIZ',
#   'AJRD',
#   'AJX',
#   'AKAM',
#   'AKR',
#   'ALB',
#   'ALGN',
#   'ALGT',
#   'ALL',
#   'ALLE',
#   'ALLY',
#   'ALOT',
#   'ALRM',
#   'ALRS',
#   'ALSN',
#   'ALTR',
#   'ALXN',
#   'AMAG',
#   'AMAT',
#   'AMBK',
#   'AMCX',
#   'AMD',
#   'AME',
#   'AMED',
#   'AMEH',
#   'AMGN',
#   'AMH',
#   'AMNB',
#   'AMP',
#   'AMRC',
#   'AMRS',
#   'AMSF',
#   'AMT',
#   'AMTD',
#   'AMWD',
#   'AMZN',
#   'AN',
#   'ANAT',
#   'ANDE',
#   'ANET',
#   'ANF',
#   'ANIK',
#   'ANSS',
#   'ANTM',
#   'AOS',
#   'AOSL',
#   'AP',
#   'APA',
#   'APD',
#   'APEI',
#   'APO',
#   'APPN',
#   'APRN',
#   'AQUA',
#   'ARA',
#   'ARAY',
#   'ARC',
#   'ARCB',
#   'ARCH',
#   'ARLP',
#   'ARMK',
#   'AROC',
#   'ARW',
#   'ASB',
#   'ASH',
#   'ASNA',
#   'ASPN',
#   'ASUR',
#   'ATGE',
#   'ATKR',
#   'ATNI',
#   'ATNX',
#   'ATO',
#   'ATRA',
#   'ATRC',
#   'ATRO',
#   'ATUS',
#   'AVA',
#   'AVAV',
#   'AVB',
#   'AVGO',
#   'AVT',
#   'AVY',
#   'AWI',
#   'AWK',
#   'AWRE',
#   'AXE',
#   'AXL',
#   'AXP',
#   'AXTA',
#   'AYI',
#   'AYX',
#   'AZO',
#   'AZPN',
#   'B',
#   'BA',
#   'BAC',
#   'BAH',
#   'BANC',
#   'BAND',
#   'BANF',
#   'BAX',
#   'BBBY',
#   'BBW',
#   'BBY',
#   'BC',
#   'BCC',
#   'BCO',
#   'BCOV',
#   'BCPC',
#   'BCTF',
#   'BDC',
#   'BEAT',
#   'BECN',
#   'BERK',
#   'BERY',
#   'BFAM',
#   'BGCP',
#   'BGFV',
#   'BGS',
#   'BH',
#   'BHB',
#   'BHE',
#   'BHF',
#   'BIG',
#   'BIIB',
#   'BJRI',
#   'BKD',
#   'BKE',
#   'BKH',
#   'BKI',
#   'BKU',
#   'BL',
#   'BLD',
#   'BLDR',
#   'BLK',
#   'BLKB',
#   'BLL',
#   'BLMN',
#   'BLUE',
#   'BMI',
#   'BMRC',
#   'BMY',
#   'BNED',
#   'BNFT',
#   'BNYN',
#   'BOH',
#   'BOKF',
#   'BOOT',
#   'BOX',
#   'BPMC',
#   'BPOP',
#   'BRC',
#   'BRKR',
#   'BRKS',
#   'BRO',
#   'BSET',
#   'BSHI',
#   'BSPA',
#   'BSX',
#   'BTU',
#   'BUSE',
#   'BV',
#   'BWA',
#   'BWEN',
#   'BWXT',
#   'BXP',
#   'BXS',
#   'BY',
#   'BYD',
#   'BZH',
#   'C',
#   'CABO',
#   'CAC',
#   'CACC',
#   'CACI',
#   'CADE',
#   'CAG',
#   'CAH',
#   'CAKE',
#   'CAL',
#   'CALB',
#   'CALX',
#   'CAPC',
#   'CAR',
#   'CARG',
#   'CARS',
#   'CASY',
#   'CAT',
#   'CATM',
#   'CATO',
#   'CB',
#   'CBB',
#   'CBOE',
#   'CBRE',
#   'CBRL',
#   'CBSH',
#   'CBT',
#   'CBU',
#   'CBZ',
#   'CC',
#   'CCBG',
#   'CCEL',
#   'CCF',
#   'CCI',
#   'CCL',
#   'CCMP',
#   'CCNE',
#   'CCO',
#   'CCOI',
#   'CCRN',
#   'CCS',
#   'CDK',
#   'CDNA',
#   'CDNS',
#   'CE',
#   'CECE',
#   'CELP',
#   'CENT',
#   'CERN',
#   'CEVA',
#   'CF',
#   'CFFN',
#   'CGIX',
#   'CGNX',
#   'CHCI',
#   'CHD',
#   'CHDN',
#   'CHEF',
#   'CHGG',
#   'CHH',
#   'CHRS',
#   'CHRW',
#   'CHS',
#   'CHSCO',
#   'CHTR',
#   'CI',
#   'CIA',
#   'CIEN',
#   'CIR',
#   'CL',
#   'CLDR',
#   'CLFD',
#   'CLGX',
#   'CLH',
#   'CLR',
#   'CLW',
#   'CLX',
#   'CMA',
#   'CMC',
#   'CMCO',
#   'CMCSA',
#   'CMD',
#   'CMG',
#   'CMI',
#   'CMLS',
#   'CMP',
#   'CMTL',
#   'CMXX',
#   'CNBKA',
#   'CNC',
#   'CNDT',
#   'CNMD',
#   'CNP',
#   'CNSL',
#   'COF',
#   'COHR',
#   'COKE',
#   'COLB',
#   'COLM',
#   'CONE',
#   'CONN',
#   'COO',
#   'COP',
#   'CORG',
#   'COST',
#   'COTY',
#   'CPB',
#   'CPK',
#   'CPRT',
#   'CR',
#   'CRBP',
#   'CREE',
#   'CRHCF',
#   'CRI',
#   'CRLKP',
#   'CRMT',
#   'CROX',
#   'CRS',
#   'CRUS',
#   'CRVL',
#   'CSCO',
#   'CSGP',
#   'CSII',
#   'CSL',
#   'CSLT',
#   'CSOD',
#   'CSPI',
#   'CSU',
#   'CSV',
#   'CSVI',
#   'CSX',
#   'CTAS',
#   'CTB',
#   'CTEK',
#   'CTL',
#   'CTLT',
#   'CTMX',
#   'CTRN',
#   'CTS',
#   'CTSH',
#   'CUB',
#   'CUBI',
#   'CUTR',
#   'CUZ',
#   'CVI',
#   'CVS',
#   'CVT',
#   'CVTI',
#   'CVX',
#   'CW',
#   'CWH',
#   'CWST',
#   'CXW',
#   'CYH',
#   'CZBS',
#   'CZR',
#   'CZWI',
#   'D',
#   'DAKT',
#   'DAR',
#   'DBD',
#   'DCO',
#   'DCOM',
#   'DCP',
#   'DDS',
#   'DE',
#   'DELL',
#   'DENN',
#   'DFIN',
#   'DFS',
#   'DG',
#   'DGX',
#   'DHI',
#   'DHX',
#   'DIN',
#   'DIS',
#   'DISCA',
#   'DISH',
#   'DLTR',
#   'DLX',
#   'DNKN',
#   'DNOW',
#   'DOOR',
#   'DORM',
#   'DOV',
#   'DPSGY',
#   'DPZ',
#   'DRAD',
#   'DRI',
#   'DSPG',
#   'DTE',
#   'DUK',
#   'DVA',
#   'DVCR',
#   'DVN',
#   'DXC',
#   'DXCM',
#   'DXLG',
#   'DXPE',
#   'DZSI',
#   'EA',
#   'EAT',
#   'EBAY',
#   'EBS',
#   'EBTC',
#   'ECHO',
#   'ECL',
#   'ECOL',
#   'ECPG',
#   'EDIT',
#   'EE',
#   'EEX',
#   'EFX',
#   'EGAN',
#   'EGBN',
#   'EGHT',
#   'EGOV',
#   'EHC',
#   'EHTH',
#   'EIGI',
#   'EIX',
#   'EL',
#   'ELS',
#   'EMC',
#   'EME',
#   'EML',
#   'EMMS',
#   'EMR',
#   'ENAB',
#   'ENBL',
#   'ENG',
#   'ENLC',
#   'ENR',
#   'ENS',
#   'ENT',
#   'ENTG',
#   'ENVA',
#   'EPAM',
#   'EPAY',
#   'EPC',
#   'EQIX',
#   'EQR',
#   'EQT',
#   'ESS',
#   'ETEC',
#   'ETFC',
#   'ETH',
#   'ETM',
#   'ETN',
#   'ETR',
#   'ETSY',
#   'EV',
#   'EVBG',
#   'EVBN',
#   'EVC',
#   'EVH',
#   'EW',
#   'EWBC',
#   'EXAS',
#   'EXC',
#   'EXCC',
#   'EXEL',
#   'EXLS',
#   'EXPO',
#   'EXPR',
#   'EXR',
#   'EXTR',
#   'EYE',
#   'EZPW',
#   'F',
#   'FARM',
#   'FARO',
#   'FAST',
#   'FB',
#   'FBAK',
#   'FBC',
#   'FBHS',
#   'FBNC',
#   'FC',
#   'FCBC',
#   'FCCO',
#   'FCF',
#   'FCN',
#   'FCX',
#   'FDX',
#   'FE',
#   'FELE',
#   'FET',
#   'FEYE',
#   'FFBC',
#   'FFIN',
#   'FFMH',
#   'FGBI',
#   'FGEN',
#   'FHB',
#   'FIBK',
#   'FISV',
#   'FIT',
#   'FIVE',
#   'FIVN',
#   'FIX',
#   'FL',
#   'FLDM',
#   'FLIR',
#   'FLOW',
#   'FLR',
#   'FLS',
#   'FLXN',
#   'FMBI',
#   'FMC',
#   'FNB',
#   'FNCB',
#   'FNF',
#   'FNWB',
#   'FORM',
#   'FORR',
#   'FOSL',
#   'FOXF',
#   'FPRX',
#   'FRAN',
#   'FRGI',
#   'FRME',
#   'FRO',
#   'FRT',
#   'FRTA',
#   'FSLR',
#   'FSS',
#   'FTLF',
#   'FTNT',
#   'FUL',
#   'FULT',
#   'FVE',
#   'FWRD',
#   'GABC',
#   'GANS',
#   'GBCI',
#   'GBT',
#   'GCFB',
#   'GCI',
#   'GCO',
#   'GCP',
#   'GD',
#   'GDDY',
#   'GDEN',
#   'GDOT',
#   'GE',
#   'GEF',
#   'GEL',
#   'GEN',
#   'GEO',
#   'GES',
#   'GHC',
#   'GIB',
#   'GIFOF',
#   'GIII',
#   'GILD',
#   'GIS',
#   'GLP',
#   'GLUU',
#   'GLW',
#   'GM',
#   'GME',
#   'GMS',
#   'GNC',
#   'GNTX',
#   'GNW',
#   'GOOGL',
#   'GPC',
#   'GPI',
#   'GPK',
#   'GPRE',
#   'GPRO',
#   'GPS',
#   'GPX',
#   'GRA',
#   'GRMN',
#   'GRPN',
#   'GRUB',
#   'GS',
#   'GSBC',
#   'GTHX',
#   'GTLS',
#   'GTT',
#   'GVA',
#   'GWB',
#   'GWW',
#   'H',
#   'HAE',
#   'HAL',
#   'HALN',
#   'HAS',
#   'HBI',
#   'HBIO',
#   'HBNC',
#   'HBP',
#   'HCA',
#   'HCCI',
#   'HCI',
#   'HCSG',
#   'HD',
#   'HDS',
#   'HDSN',
#   'HEES',
#   'HEI',
#   'HELE',
#   'HES',
#   'HGV',
#   'HHC',
#   'HIBB',
#   'HII',
#   'HIL',
#   'HIW',
#   'HLI',
#   'HLT',
#   'HMHC',
#   'HMN',
#   'HMST',
#   'HMSY',
#   'HNGR',
#   'HNI',
#   'HOG',
#   'HOLX',
#   'HON',
#   'HPE',
#   'HPP',
#   'HPQ',
#   'HQY',
#   'HR',
#   'HRB',
#   'HRL',
#   'HSC',
#   'HSIC',
#   'HSTM',
#   'HSY',
#   'HT',
#   'HTGM',
#   'HTH',
#   'HTLD',
#   'HTZ',
#   'HUBB',
#   'HUBG',
#   'HUBS',
#   'HUM',
#   'HUN',
#   'HURN',
#   'HVT',
#   'HWKN',
#   'HXL',
#   'HY',
#   'HZNP',
#   'HZO',
#   'IART',
#   'IBKC',
#   'IBM',
#   'IBP',
#   'ICE',
#   'ICFI',
#   'ICUI',
#   'IDT',
#   'IESC',
#   'IEX',
#   'IFF',
#   'IHG',
#   'III',
#   'ILMN',
#   'IMAX',
#   'IMKTA',
#   'IMMU',
#   'INBK',
#   'INCY',
#   'INFN',
#   'INGN',
#   'INGR',
#   'INOV',
#   'INSM',
#   'INT',
#   'INTC',
#   'INTL',
#   'INTU',
#   'INVH',
#   'INWK',
#   'IP',
#   'IPHI',
#   'IR',
#   'IRBT',
#   'IRM',
#   'ISBC',
#   'ISDR',
#   'ISRG',
#   'IT',
#   'ITEX',
#   'ITI',
#   'ITRI',
#   'IVC',
#   'IVZ',
#   'IZEA',
#   'JACK',
#   'JAKK',
#   'JBHT',
#   'JBL',
#   'JBLU',
#   'JCI',
#   'JKHY',
#   'JNCE',
#   'JNJ',
#   'JNPR',
#   'JPM',
#   'JSDA',
#   'JWN',
#   'K',
#   'KALU',
#   'KAR',
#   'KBAL',
#   'KBH',
#   'KBR',
#   'KDP',
#   'KEQU',
#   'KEX',
#   'KEYS',
#   'KFRC',
#   'KGHI',
#   'KHC',
#   'KIRK',
#   'KLIC',
#   'KMI',
#   'KMPR',
#   'KMT',
#   'KMX',
#   'KN',
#   'KNL',
#   'KNX',
#   'KO',
#   'KR',
#   'KSS',
#   'KTOS',
#   'KTYB',
#   'L',
#   'LAD',
#   'LAMR',
#   'LARK',
#   'LAUR',
#   'LAWS',
#   'LB',
#   'LBAI',
#   'LC',
#   'LCI',
#   'LCNB',
#   'LCUT',
#   'LDOS',
#   'LE',
#   'LEA',
#   'LECO',
#   'LEE',
#   'LEG',
#   'LEN',
#   'LGIH',
#   'LHCG',
#   'LIND',
#   'LKQ',
#   'LL',
#   'LM',
#   'LMNX',
#   'LMT',
#   'LNG',
#   'LNN',
#   'LNT',
#   'LOCMQ',
#   'LOCO',
#   'LOGM',
#   'LOW',
#   'LPLA',
#   'LPSN',
#   'LRCX',
#   'LRN',
#   'LSI',
#   'LSTR',
#   'LTRX',
#   'LUNA',
#   'LUV',
#   'LVS',
#   'LW',
#   'LYB',
#   'LZB',
#   'M',
#   'MA',
#   'MAC',
#   'MAN',
#   'MANH',
#   'MANT',
#   'MAR',
#   'MAS',
#   'MASI',
#   'MAT',
#   'MATW',
#   'MBII',
#   'MCD',
#   'MCHP',
#   'MCHX',
#   'MCK',
#   'MCS',
#   'MD',
#   'MDB',
#   'MDC',
#   'MDLZ',
#   'MDP',
#   'MDRX',
#   'MDT',
#   'MDU',
#   'MDXG',
#   'MED',
#   'MEDD',
#   'MEDP',
#   'MET',
#   'MG',
#   'MGLN',
#   'MGM',
#   'MGRC',
#   'MHGU',
#   'MHH',
#   'MHK',
#   'MIK',
#   'MINI',
#   'MITK',
#   'MKL',
#   'MLHR',
#   'MLI',
#   'MLM',
#   'MLR',
#   'MMC',
#   'MMM',
#   'MMP',
#   'MMS',
#   'MMSI',
#   'MNK',
#   'MNKD',
#   'MNRO',
#   'MO',
#   'MOBL',
#   'MOD',
#   'MOFG',
#   'MOH',
#   'MORN',
#   'MOS',
#   'MOV',
#   'MPB',
#   'MPC',
#   'MRC',
#   'MRCY',
#   'MRK',
#   'MRTN',
#   'MS',
#   'MSA',
#   'MSBI',
#   'MSCI',
#   'MSFT',
#   'MSI',
#   'MSM',
#   'MTB',
#   'MTD',
#   'MTEM',
#   'MTH',
#   'MTN',
#   'MTOR',
#   'MTRN',
#   'MTRX',
#   'MTSC',
#   'MTZ',
#   'MUR',
#   'MWA',
#   'MXIM',
#   'MYGN',
#   'MYL',
#   'MYOK',
#   'MYRG',
#   'NATI',
#   'NAUH',
#   'NAV',
#   'NAVI',
#   'NBL',
#   'NBN',
#   'NBTB',
#   'NCMI',
#   'NCR',
#   'NCSM',
#   'NDAQ',
#   'NDLS',
#   'NDSN',
#   'NEE',
#   'NEM',
#   'NEO',
#   'NEOG',
#   'NES',
#   'NEWR',
#   'NEWT',
#   'NFLX',
#   'NGHC',
#   'NGL',
#   'NGVC',
#   'NGVT',
#   'NHC',
#   'NI',
#   'NK',
#   'NKE',
#   'NLS',
#   'NNBR',
#   'NNI',
#   'NOC',
#   'NOV',
#   'NOVT',
#   'NOW',
#   'NPO',
#   'NR',
#   'NRC',
#   'NRG',
#   'NRIM',
#   'NS',
#   'NSC',
#   'NSIT',
#   'NSRGY',
#   'NTAP',
#   'NTGR',
#   'NTNX',
#   'NTRA',
#   'NUE',
#   'NUS',
#   'NUVA',
#   'NVDA',
#   'NVEE',
#   'NVR',
#   'NVRO',
#   'NVTA',
#   'NVTR',
#   'NWL',
#   'NWSA',
#   'NX',
#   'NYT',
#   'O',
#   'OAS',
#   'OC',
#   'OCUL',
#   'ODFL',
#   'ODP',
#   'OGE',
#   'OGS',
#   'OI',
#   'OII',
#   'OIS',
#   'OKE',
#   'OKTA',
#   'OLLI',
#   'OLN',
#   'OMCL',
#   'OMF',
#   'OMI',
#   'ONB',
#   'OOMA',
#   'OPTI',
#   'OPTN',
#   'ORBC',
#   'ORCL',
#   'ORLY',
#   'OSK',
#   'OSTK',
#   'OTTR',
#   'OUT',
#   'OXBC',
#   'OXY',
#   'PAA',
#   'PAG',
#   'PANW',
#   'PAOS',
#   'PARF',
#   'PATK',
#   'PAYX',
#   'PB',
#   'PBCT',
#   'PBF',
#   ...],
#  '2019-09': ['A',
#   'AA',
#   'AAL',
#   'AAN',
#   'AAP',
#   'AAPL',
#   'AAWW',
#   'AB',
#   'ABBV',
#   'ABC',
#   'ABCB',
#   'ABG',
#   'ABMD',
#   'ABT',
#   'ACAD',
#   'ACC',
#   'ACCO',
#   'ACHC',
#   'ACIA',
#   'ACIW',
#   'ACLS',
#   'ACM',
#   'ACN',
#   'ACNB',
#   'ADBE',
#   'ADDDF',
#   'ADI',
#   'ADM',
#   'ADP',
#   'ADS',
#   'ADSK',
#   'ADSW',
#   'ADT',
#   'ADUS',
#   'AEE',
#   'AEIS',
#   'AEO',
#   'AEP',
#   'AES',
#   'AEYE',
#   'AFG',
#   'AFI',
#   'AFL',
#   'AGEN',
#   'AGIO',
#   'AGO',
#   'AGR',
#   'AGYS',
#   'AHII',
#   'AIMC',
#   'AIMT',
#   'AIN',
#   'AIR',
#   'AIT',
#   'AIZ',
#   'AJRD',
#   'AJX',
#   'AKAM',
#   'ALB',
#   'ALE',
#   'ALG',
#   'ALGN',
#   'ALGT',
#   'ALL',
#   'ALLE',
#   'ALLY',
#   'ALRM',
#   'ALRS',
#   'ALSN',
#   'ALTR',
#   'ALXN',
#   'AMAG',
#   'AMAT',
#   'AMBK',
#   'AMCX',
#   'AMD',
#   'AME',
#   'AMED',
#   'AMGN',
#   'AMH',
#   'AMN',
#   'AMNB',
#   'AMOT',
#   'AMP',
#   'AMRC',
#   'AMT',
#   'AMTD',
#   'AMWD',
#   'AMZN',
#   'AN',
#   'ANAT',
#   'ANDE',
#   'ANET',
#   'ANF',
#   'ANGO',
#   'ANMP',
#   'ANSS',
#   'ANTM',
#   'AON',
#   'AOS',
#   'AOSL',
#   'AP',
#   'APA',
#   'APAM',
#   'APD',
#   'APEI',
#   'APH',
#   'APO',
#   'APPF',
#   'APPN',
#   'APRN',
#   'AQMS',
#   'ARA',
#   'ARAY',
#   'ARBU',
#   'ARC',
#   'ARCB',
#   'ARCH',
#   'ARLP',
#   'ARMK',
#   'AROC',
#   'ARW',
#   'ASB',
#   'ASH',
#   'ASNA',
#   'ASPN',
#   'ASUR',
#   'ATGE',
#   'ATKR',
#   'ATNI',
#   'ATNX',
#   'ATO',
#   'ATRA',
#   'ATRC',
#   'ATRO',
#   'ATUS',
#   'AVA',
#   'AVAV',
#   'AVB',
#   'AVBH',
#   'AVGG',
#   'AVGO',
#   'AVT',
#   'AVY',
#   'AWI',
#   'AWK',
#   'AWRE',
#   'AXE',
#   'AXGN',
#   'AXL',
#   'AXP',
#   'AYI',
#   'AYX',
#   'AZO',
#   'AZPN',
#   'AZZ',
#   'B',
#   'BA',
#   'BABA',
#   'BAC',
#   'BAH',
#   'BANC',
#   'BAND',
#   'BANF',
#   'BAX',
#   'BBBK',
#   'BBBY',
#   'BBSI',
#   'BBW',
#   'BBY',
#   'BC',
#   'BCC',
#   'BCO',
#   'BCOR',
#   'BCOV',
#   'BDC',
#   'BECN',
#   'BERK',
#   'BERY',
#   'BFAM',
#   'BFIN',
#   'BGCP',
#   'BGFV',
#   'BGS',
#   'BH',
#   'BHB',
#   'BHE',
#   'BHF',
#   'BHWB',
#   'BIG',
#   'BJRI',
#   'BKD',
#   'BKE',
#   'BKH',
#   'BKI',
#   'BKU',
#   'BL',
#   'BLD',
#   'BLDR',
#   'BLFS',
#   'BLK',
#   'BLKB',
#   'BLL',
#   'BLMN',
#   'BLUE',
#   'BMI',
#   'BMRC',
#   'BMY',
#   'BNED',
#   'BNFT',
#   'BNYN',
#   'BOH',
#   'BOKF',
#   'BOOT',
#   'BOX',
#   'BPMC',
#   'BPOP',
#   'BRC',
#   'BREW',
#   'BRKL',
#   'BRKR',
#   'BRKS',
#   'BRO',
#   'BSET',
#   'BSHI',
#   'BSX',
#   'BUSE',
#   'BV',
#   'BW',
#   'BWA',
#   'BWXT',
#   'BXP',
#   'BXS',
#   'BY',
#   'BYD',
#   'BZH',
#   'C',
#   'CABO',
#   'CAC',
#   'CACC',
#   'CACI',
#   'CADE',
#   'CAG',
#   'CAH',
#   'CAKE',
#   'CAL',
#   'CALB',
#   'CALM',
#   'CALX',
#   'CAMP',
#   'CAPC',
#   'CAR',
#   'CARG',
#   'CARS',
#   'CASY',
#   'CAT',
#   'CATM',
#   'CATO',
#   'CATS',
#   'CB',
#   'CBB',
#   'CBL',
#   'CBOE',
#   'CBRE',
#   'CBRL',
#   'CBSH',
#   'CBU',
#   'CBZ',
#   'CCBG',
#   'CCC',
#   'CCF',
#   'CCI',
#   'CCL',
#   'CCLP',
#   'CCMP',
#   'CCNE',
#   'CCO',
#   'CCOI',
#   'CCRN',
#   'CCS',
#   'CDK',
#   'CDNA',
#   'CDNS',
#   'CE',
#   'CECE',
#   'CEMI',
#   'CENT',
#   'CERN',
#   'CEVA',
#   'CF',
#   'CFFN',
#   'CFMS',
#   'CGIX',
#   'CGNX',
#   'CHD',
#   'CHGG',
#   'CHH',
#   'CHRS',
#   'CHRW',
#   'CHS',
#   'CHSCO',
#   'CHTR',
#   'CI',
#   'CIA',
#   'CIEN',
#   'CIR',
#   'CIT',
#   'CIVB',
#   'CKH',
#   'CL',
#   'CLCN',
#   'CLDR',
#   'CLFD',
#   'CLGX',
#   'CLH',
#   'CLMT',
#   'CLR',
#   'CLW',
#   'CLX',
#   'CMA',
#   'CMC',
#   'CMCO',
#   'CMCSA',
#   'CMD',
#   'CMG',
#   'CMI',
#   'CMLS',
#   'CMP',
#   'CMTV',
#   'CMXX',
#   'CNBKA',
#   'CNC',
#   'CNDT',
#   'CNMD',
#   'CNND',
#   'CNP',
#   'CNS',
#   'CNSL',
#   'COF',
#   'COHR',
#   'COKE',
#   'COL',
#   'COLB',
#   'COLM',
#   'CONE',
#   'CONN',
#   'COO',
#   'COP',
#   'COST',
#   'COTY',
#   'CPB',
#   'CPFH',
#   'CPK',
#   'CPRT',
#   'CR',
#   'CRBP',
#   'CREE',
#   'CRHCF',
#   'CRI',
#   'CRLKP',
#   'CRMT',
#   'CROX',
#   'CRS',
#   'CRSP',
#   'CRUS',
#   'CRVL',
#   'CSCO',
#   'CSGP',
#   'CSII',
#   'CSL',
#   'CSLT',
#   'CSOD',
#   'CSPI',
#   'CSU',
#   'CSV',
#   'CSVI',
#   'CSX',
#   'CTAS',
#   'CTB',
#   'CTEK',
#   'CTL',
#   'CTLT',
#   'CTMX',
#   'CTRN',
#   'CTS',
#   'CTSH',
#   'CUB',
#   'CUBI',
#   'CUTR',
#   'CVCY',
#   'CVI',
#   'CVS',
#   'CVT',
#   'CVTI',
#   'CVX',
#   'CW',
#   'CWH',
#   'CWST',
#   'CXW',
#   'CYH',
#   'CZBS',
#   'CZR',
#   'D',
#   'DAKT',
#   'DAL',
#   'DAN',
#   'DAR',
#   'DBD',
#   'DCI',
#   'DCO',
#   'DDS',
#   'DE',
#   'DELL',
#   'DENN',
#   'DFIN',
#   'DFS',
#   'DG',
#   'DGX',
#   'DHI',
#   'DHX',
#   'DIN',
#   'DIS',
#   'DISCA',
#   'DISH',
#   'DJCO',
#   'DLTR',
#   'DLX',
#   'DNKN',
#   'DNOW',
#   'DOOR',
#   'DORM',
#   'DOV',
#   'DOW',
#   'DPSGY',
#   'DPZ',
#   'DRAD',
#   'DRI',
#   'DS',
#   'DSPG',
#   'DTE',
#   'DUK',
#   'DVA',
#   'DVCR',
#   'DVN',
#   'DXCM',
#   'DXLG',
#   'DXPE',
#   'DYNT',
#   'EA',
#   'EAT',
#   'EBAY',
#   'EBS',
#   'EBTC',
#   'ECHO',
#   'ECL',
#   'ECOL',
#   'ECOM',
#   'EDIT',
#   'EEX',
#   'EFX',
#   'EGBN',
#   'EGHT',
#   'EGOV',
#   'EHC',
#   'EHTH',
#   'EIG',
#   'EIX',
#   'EL',
#   'ELGX',
#   'ELS',
#   'EMC',
#   'EME',
#   'EML',
#   'EMMS',
#   'EMR',
#   'ENAB',
#   'ENBL',
#   'ENLC',
#   'ENPH',
#   'ENR',
#   'ENS',
#   'ENTG',
#   'ENVA',
#   'EPAM',
#   'EPC',
#   'EQIX',
#   'EQR',
#   'ES',
#   'ESS',
#   'ETEC',
#   'ETFC',
#   'ETH',
#   'ETM',
#   'ETN',
#   'ETR',
#   'ETSY',
#   'EUOT',
#   'EV',
#   'EVBG',
#   'EVBN',
#   'EVC',
#   'EVH',
#   'EVRG',
#   'EW',
#   'EWBC',
#   'EXAS',
#   'EXC',
#   'EXCC',
#   'EXEL',
#   'EXLS',
#   'EXPO',
#   'EXPR',
#   'EXR',
#   'EXTR',
#   'EYE',
#   'F',
#   'FARM',
#   'FARO',
#   'FAST',
#   'FB',
#   'FBAK',
#   'FBC',
#   'FBM',
#   'FBNC',
#   'FC',
#   'FCBC',
#   'FCF',
#   'FCFS',
#   'FCN',
#   'FCX',
#   'FDX',
#   'FET',
#   'FFBC',
#   'FFIN',
#   'FFMH',
#   'FFNW',
#   'FGEN',
#   'FHB',
#   'FIBK',
#   'FISV',
#   'FIT',
#   'FIVE',
#   'FIVN',
#   'FIX',
#   'FIZZ',
#   'FL',
#   'FLIR',
#   'FLOW',
#   'FLR',
#   'FLS',
#   'FLWS',
#   'FLXN',
#   'FLXS',
#   'FMBH',
#   'FMBI',
#   'FMC',
#   'FMCB',
#   'FMCC',
#   'FNB',
#   'FNCB',
#   'FND',
#   'FNKO',
#   'FOLD',
#   'FORM',
#   'FORR',
#   'FOSL',
#   'FOXF',
#   'FRAN',
#   'FRGI',
#   'FRME',
#   'FRO',
#   'FRTA',
#   'FSLR',
#   'FSS',
#   'FSTR',
#   'FTLF',
#   'FTNT',
#   'FUL',
#   'FULT',
#   'FUNC',
#   'FVE',
#   'FWRD',
#   'GABC',
#   'GANS',
#   'GATX',
#   'GBCI',
#   'GBT',
#   'GCAP',
#   'GCI',
#   'GCO',
#   'GCP',
#   'GD',
#   'GDDY',
#   'GDEN',
#   'GDOT',
#   'GE',
#   'GEF',
#   'GEL',
#   'GEO',
#   'GES',
#   'GFNL',
#   'GGG',
#   'GHC',
#   'GIB',
#   'GIFOF',
#   'GIII',
#   'GILD',
#   'GIS',
#   'GLDD',
#   'GLP',
#   'GLW',
#   'GM',
#   'GME',
#   'GMED',
#   'GMS',
#   'GNC',
#   'GNW',
#   'GOOGL',
#   'GPC',
#   'GPI',
#   'GPK',
#   'GPRE',
#   'GPS',
#   'GPX',
#   'GRA',
#   'GRMN',
#   'GRPN',
#   'GRRB',
#   'GRUB',
#   'GS',
#   'GSBC',
#   'GTHX',
#   'GTLS',
#   'GTT',
#   'GVA',
#   'GWB',
#   'GWRE',
#   'GWW',
#   'H',
#   'HAE',
#   'HAL',
#   'HALN',
#   'HAS',
#   'HBB',
#   'HBCP',
#   'HBI',
#   'HBNC',
#   'HBP',
#   'HCCI',
#   'HCI',
#   'HCSG',
#   'HD',
#   'HDS',
#   'HEES',
#   'HEI',
#   'HELE',
#   'HES',
#   'HFBK',
#   'HGV',
#   'HHC',
#   'HHS',
#   'HIBB',
#   'HII',
#   'HIL',
#   'HIW',
#   'HLI',
#   'HLIT',
#   'HLT',
#   'HMHC',
#   'HMN',
#   'HMST',
#   'HMSY',
#   'HNGR',
#   'HNI',
#   'HOG',
#   'HOLX',
#   'HON',
#   'HPE',
#   'HPP',
#   'HPQ',
#   'HQY',
#   'HR',
#   'HRB',
#   'HRL',
#   'HSC',
#   'HSIC',
#   'HSTM',
#   'HSY',
#   'HTBI',
#   'HTH',
#   'HTLD',
#   'HTLF',
#   'HTZ',
#   'HUBB',
#   'HUBG',
#   'HUBS',
#   'HUM',
#   'HUN',
#   'HURN',
#   'HVT',
#   'HWCC',
#   'HWKN',
#   'HXL',
#   'HY',
#   'HZNP',
#   'HZO',
#   'IART',
#   'IBKC',
#   'IBM',
#   'IBOC',
#   'IBP',
#   'ICE',
#   'ICFI',
#   'ICPT',
#   'ICUI',
#   'IDCC',
#   'IDT',
#   'IDTY',
#   'IEC',
#   'IESC',
#   'IEX',
#   'IFF',
#   'IFNY',
#   'IHG',
#   'III',
#   'IIVI',
#   'ILMN',
#   'IMAX',
#   'IMGN',
#   'IMKTA',
#   'IMMR',
#   'IMMU',
#   'INCY',
#   'INDB',
#   'INFN',
#   'INGN',
#   'INGR',
#   'INOV',
#   'INSG',
#   'INT',
#   'INTC',
#   'INTU',
#   'INUV',
#   'INVH',
#   'INWK',
#   'IONS',
#   'IOTS',
#   'IP',
#   'IPGP',
#   'IPHI',
#   'IR',
#   'IRBT',
#   'IRM',
#   'ISBA',
#   'ISBC',
#   'ISDR',
#   'ISIG',
#   'ISRG',
#   'IT',
#   'ITRI',
#   'ITT',
#   'IVZ',
#   'IZEA',
#   'JACK',
#   'JAX',
#   'JBHT',
#   'JBL',
#   'JBLU',
#   'JBT',
#   'JCI',
#   'JJSF',
#   'JKHY',
#   'JNCE',
#   'JNJ',
#   'JNPR',
#   'JOE',
#   'JPM',
#   'JWN',
#   'JYNT',
#   'K',
#   'KAR',
#   'KBAL',
#   'KBH',
#   'KBR',
#   'KDP',
#   'KEQU',
#   'KEX',
#   'KEYS',
#   'KFRC',
#   'KGHI',
#   'KHC',
#   'KIRK',
#   'KLAC',
#   'KLIC',
#   'KMB',
#   'KMI',
#   'KMPR',
#   'KMT',
#   'KMX',
#   'KN',
#   'KNL',
#   'KNX',
#   'KO',
#   'KR',
#   'KSS',
#   'KSU',
#   'KTOS',
#   'KVHI',
#   'KVIL',
#   'KWR',
#   'L',
#   'LAD',
#   'LAMR',
#   'LARK',
#   'LAUR',
#   'LAWS',
#   'LB',
#   'LBAI',
#   'LC',
#   'LCI',
#   'LDOS',
#   'LE',
#   'LEA',
#   'LECO',
#   'LEE',
#   'LEG',
#   'LEN',
#   'LFUS',
#   'LGIH',
#   'LHCG',
#   'LIND',
#   'LKQ',
#   'LL',
#   'LMAT',
#   'LMNX',
#   'LMT',
#   'LNN',
#   'LOCMQ',
#   'LOCO',
#   'LOGM',
#   'LOW',
#   'LPLA',
#   'LPSN',
#   'LPTH',
#   'LRCX',
#   'LRN',
#   'LSI',
#   'LSTR',
#   'LTRE',
#   'LTRX',
#   'LUV',
#   'LUVU',
#   'LVS',
#   'LW',
#   'LYB',
#   'LZB',
#   'M',
#   'MA',
#   'MAN',
#   'MANH',
#   'MANT',
#   'MAR',
#   'MAS',
#   'MASI',
#   'MAT',
#   'MBII',
#   'MCBC',
#   'MCD',
#   'MCHP',
#   'MCHX',
#   'MCK',
#   'MCS',
#   'MD',
#   'MDB',
#   'MDC',
#   'MDLZ',
#   'MDP',
#   'MDRX',
#   'MDT',
#   'MDXG',
#   'MED',
#   'MEDD',
#   'MEDP',
#   'MET',
#   'MG',
#   'MGLN',
#   'MGM',
#   'MGNX',
#   'MGRC',
#   'MHGU',
#   'MHH',
#   'MHK',
#   'MHO',
#   'MIK',
#   'MINI',
#   'MKL',
#   'MKSI',
#   'MLHR',
#   'MLM',
#   'MMC',
#   'MMM',
#   'MMP',
#   'MMS',
#   'MMSI',
#   'MNK',
#   'MNRO',
#   'MO',
#   'MOBL',
#   'MOD',
#   'MOFG',
#   'MOH',
#   'MOS',
#   'MPB',
#   'MPC',
#   'MPWR',
#   'MRC',
#   'MRCY',
#   'MRK',
#   'MRTN',
#   'MS',
#   'MSBI',
#   'MSCI',
#   'MSFT',
#   'MSI',
#   'MSM',
#   'MTB',
#   'MTD',
#   'MTEX',
#   'MTH',
#   'MTN',
#   'MTOR',
#   'MTRN',
#   'MTSC',
#   'MTX',
#   'MTZ',
#   'MUEL',
#   'MWA',
#   'MXIM',
#   'MYGN',
#   'MYL',
#   'MYOK',
#   'MYRG',
#   'NATI',
#   'NAV',
#   'NAVI',
#   'NBL',
#   'NBTB',
#   'NCMI',
#   'NCR',
#   'NDAQ',
#   'NDLS',
#   'NDSN',
#   'NEE',
#   'NEM',
#   'NEO',
#   'NEOG',
#   'NEOS',
#   'NES',
#   'NEWR',
#   'NEWT',
#   'NFG',
#   'NFLX',
#   'NGHC',
#   'NGL',
#   'NGVC',
#   'NGVT',
#   'NH',
#   'NHC',
#   'NI',
#   'NJR',
#   'NKE',
#   'NLS',
#   'NNI',
#   'NOC',
#   'NOV',
#   'NOVT',
#   'NOW',
#   'NP',
#   'NPO',
#   'NR',
#   'NRC',
#   'NRG',
#   'NS',
#   'NSC',
#   'NSIT',
#   'NSP',
#   'NSRGY',
#   'NTAP',
#   'NTGR',
#   'NTNX',
#   'NTRA',
#   'NUS',
#   'NUVA',
#   'NVDA',
#   'NVEE',
#   'NVR',
#   'NVRO',
#   'NVTA',
#   'NVTR',
#   'NWL',
#   ...],
#  '2019-10': ['A',
#   'AA',
#   'AAL',
#   'AAN',
#   'AAP',
#   'AAWW',
#   'AB',
#   'ABBV',
#   'ABC',
#   'ABCB',
#   'ABG',
#   'ABM',
#   'ABMD',
#   'ABT',
#   'ACAD',
#   'ACBI',
#   'ACC',
#   'ACCO',
#   'ACHC',
#   'ACIA',
#   'ACIW',
#   'ACLS',
#   'ACN',
#   'ADBE',
#   'ADDDF',
#   'ADI',
#   'ADM',
#   'ADP',
#   'ADSK',
#   'ADSW',
#   'ADT',
#   'ADUS',
#   'AEE',
#   'AEIS',
#   'AEO',
#   'AES',
#   'AFG',
#   'AFI',
#   'AFL',
#   'AGCO',
#   'AGIO',
#   'AGO',
#   'AGYS',
#   'AHH',
#   'AIMC',
#   'AIMT',
#   'AIN',
#   'AIR',
#   'AIRI',
#   'AIT',
#   'AIZ',
#   'AJRD',
#   'AKAM',
#   'AKBA',
#   'ALG',
#   'ALGN',
#   'ALGT',
#   'ALLE',
#   'ALLY',
#   'ALRM',
#   'ALRS',
#   'ALSN',
#   'ALXN',
#   'AMAG',
#   'AMAT',
#   'AMD',
#   'AME',
#   'AMED',
#   'AMGN',
#   'AMH',
#   'AMN',
#   'AMNB',
#   'AMP',
#   'AMRC',
#   'AMSC',
#   'AMSF',
#   'AMT',
#   'AMTD',
#   'AMWD',
#   'AMZN',
#   'AN',
#   'ANAT',
#   'ANDE',
#   'ANF',
#   'ANMP',
#   'ANSS',
#   'ANTM',
#   'AOS',
#   'APD',
#   'APEI',
#   'APEN',
#   'APO',
#   'APPF',
#   'APPN',
#   'APRN',
#   'ARA',
#   'ARAY',
#   'ARBU',
#   'ARC',
#   'ARCB',
#   'ARLP',
#   'AROC',
#   'ARTW',
#   'ASB',
#   'ASH',
#   'ASNA',
#   'ASPN',
#   'ASUR',
#   'ATEN',
#   'ATGE',
#   'ATKR',
#   'ATO',
#   'ATRA',
#   'ATRO',
#   'ATUS',
#   'AVAV',
#   'AVB',
#   'AVGO',
#   'AVID',
#   'AVT',
#   'AVY',
#   'AWK',
#   'AWRE',
#   'AXDX',
#   'AXE',
#   'AXL',
#   'AXP',
#   'AXTA',
#   'AYI',
#   'AYX',
#   'AZO',
#   'AZPN',
#   'B',
#   'BA',
#   'BABA',
#   'BAC',
#   'BAH',
#   'BAND',
#   'BANF',
#   'BAX',
#   'BBBK',
#   'BBBY',
#   'BBW',
#   'BBY',
#   'BCC',
#   'BCO',
#   'BCOV',
#   'BCPC',
#   'BDC',
#   'BEAT',
#   'BECN',
#   'BERK',
#   'BERY',
#   'BFAM',
#   'BFIN',
#   'BGCP',
#   'BGFV',
#   'BH',
#   'BHB',
#   'BIIB',
#   'BJRI',
#   'BKD',
#   'BKE',
#   'BKI',
#   'BKU',
#   'BL',
#   'BLDR',
#   'BLKB',
#   'BLL',
#   'BLMN',
#   'BLUE',
#   'BMI',
#   'BMRC',
#   'BMY',
#   'BNED',
#   'BNFT',
#   'BOH',
#   'BOKF',
#   'BOOT',
#   'BOX',
#   'BPMC',
#   'BPOP',
#   'BRC',
#   'BREW',
#   'BRKR',
#   'BRKS',
#   'BRO',
#   'BSET',
#   'BSPA',
#   'BSX',
#   'BV',
#   'BW',
#   'BWXT',
#   'BXP',
#   'BXS',
#   'BY',
#   'BYD',
#   'BZH',
#   'C',
#   'CAC',
#   'CACC',
#   'CACI',
#   'CADE',
#   'CAG',
#   'CAH',
#   'CAKE',
#   'CAL',
#   'CALB',
#   'CALX',
#   'CAMP',
#   'CAR',
#   'CARG',
#   'CARS',
#   'CASY',
#   'CAT',
#   'CATM',
#   'CATO',
#   'CB',
#   'CBRL',
#   'CBSH',
#   'CBT',
#   'CBU',
#   'CBZ',
#   'CC',
#   'CCBG',
#   'CCC',
#   'CCEL',
#   'CCF',
#   'CCI',
#   'CCL',
#   'CCLP',
#   'CCNE',
#   'CCO',
#   'CCOI',
#   'CCRN',
#   'CCS',
#   'CCXI',
#   'CDK',
#   'CDNA',
#   'CDNS',
#   'CECE',
#   'CELP',
#   'CERN',
#   'CEVA',
#   'CF',
#   'CFFN',
#   'CGNX',
#   'CHCI',
#   'CHD',
#   'CHEF',
#   'CHGG',
#   'CHH',
#   'CHRS',
#   'CHRW',
#   'CHS',
#   'CHSCO',
#   'CHTR',
#   'CHUY',
#   'CI',
#   'CIA',
#   'CIEN',
#   'CIR',
#   'CIT',
#   'CL',
#   'CLDR',
#   'CLFD',
#   'CLGX',
#   'CLH',
#   'CLMT',
#   'CLX',
#   'CMA',
#   'CMC',
#   'CMCO',
#   'CMCSA',
#   'CMD',
#   'CME',
#   'CMG',
#   'CMI',
#   'CMLS',
#   'CMP',
#   'CMTL',
#   'CMTV',
#   'CNC',
#   'CNDT',
#   'CNMD',
#   'CNP',
#   'CNS',
#   'CNSL',
#   'COF',
#   'COHN',
#   'COHR',
#   'COKE',
#   'COLB',
#   'COLL',
#   'CONN',
#   'COO',
#   'COP',
#   'CORT',
#   'COST',
#   'COTY',
#   'CPB',
#   'CPK',
#   'CPRT',
#   'CR',
#   'CREE',
#   'CRHCF',
#   'CRI',
#   'CRLKP',
#   'CRMT',
#   'CROX',
#   'CRS',
#   'CRUS',
#   'CSCO',
#   'CSGP',
#   'CSII',
#   'CSL',
#   'CSLT',
#   'CSOD',
#   'CSU',
#   'CSV',
#   'CTAS',
#   'CTB',
#   'CTBI',
#   'CTEK',
#   'CTL',
#   'CTLT',
#   'CTMX',
#   'CTRN',
#   'CTS',
#   'CTSH',
#   'CUB',
#   'CUZ',
#   'CVCO',
#   'CVI',
#   'CVS',
#   'CVT',
#   'CVTI',
#   'CVX',
#   'CW',
#   'CWH',
#   'CWST',
#   'CXW',
#   'CYH',
#   'CZBS',
#   'D',
#   'DAKT',
#   'DAL',
#   'DAN',
#   'DAR',
#   'DCI',
#   'DCO',
#   'DCOM',
#   'DCP',
#   'DDD',
#   'DDS',
#   'DE',
#   'DELL',
#   'DENN',
#   'DFIN',
#   'DFS',
#   'DG',
#   'DGX',
#   'DIN',
#   'DIS',
#   'DISCA',
#   'DISH',
#   'DLTR',
#   'DLX',
#   'DNKN',
#   'DORM',
#   'DOV',
#   'DOW',
#   'DPSGY',
#   'DPZ',
#   'DRAD',
#   'DS',
#   'DTE',
#   'DUK',
#   'DVA',
#   'DVCR',
#   'DXC',
#   'DXCM',
#   'DXLG',
#   'DXPE',
#   'EA',
#   'EAT',
#   'EBAY',
#   'EBF',
#   'EBS',
#   'EBTC',
#   'ECHO',
#   'ECL',
#   'ECOL',
#   'EFX',
#   'EGBN',
#   'EGHT',
#   'EGOV',
#   'EHC',
#   'EHTH',
#   'EIG',
#   'EIGI',
#   'EIX',
#   'EL',
#   'ELS',
#   'EME',
#   'EMR',
#   'ENBL',
#   'ENG',
#   'ENLC',
#   'ENPH',
#   'ENR',
#   'ENS',
#   'ENTG',
#   'ENVA',
#   'EPAM',
#   'EPC',
#   'EQIX',
#   'EQR',
#   'ES',
#   'ETFC',
#   'ETH',
#   'ETM',
#   'ETN',
#   'ETR',
#   'ETSY',
#   'EUOT',
#   'EV',
#   'EVBG',
#   'EVBN',
#   'EVC',
#   'EVH',
#   'EW',
#   'EWBC',
#   'EXAS',
#   'EXC',
#   'EXEL',
#   'EXPO',
#   'EXPR',
#   'EXR',
#   'EXTR',
#   'EYE',
#   'F',
#   'FARM',
#   'FARO',
#   'FAST',
#   'FB',
#   'FBAK',
#   'FBC',
#   'FBHS',
#   'FBNC',
#   'FC',
#   'FCBC',
#   'FCF',
#   'FCFS',
#   'FCN',
#   'FCX',
#   'FDX',
#   'FELE',
#   'FET',
#   'FFBC',
#   'FFIN',
#   'FFMH',
#   'FFNW',
#   'FGEN',
#   'FHB',
#   'FIBK',
#   'FISV',
#   'FIT',
#   'FIVE',
#   'FIVN',
#   'FIZZ',
#   'FL',
#   'FLDM',
#   'FLIR',
#   'FLOW',
#   'FLR',
#   'FLS',
#   'FNB',
#   'FND',
#   'FNF',
#   'FNKO',
#   'FNWB',
#   'FOLD',
#   'FORM',
#   'FORR',
#   'FOSL',
#   'FPCG',
#   'FPRX',
#   'FRO',
#   'FRTA',
#   'FSLR',
#   'FSS',
#   'FSTR',
#   'FTLF',
#   'FUL',
#   'FULT',
#   'FUNC',
#   'FVE',
#   'FWRD',
#   'GBCI',
#   'GBT',
#   'GCI',
#   'GCO',
#   'GCP',
#   'GD',
#   'GDDY',
#   'GDEN',
#   'GDOT',
#   'GE',
#   'GEF',
#   'GEN',
#   'GFNL',
#   'GHC',
#   'GIB',
#   'GIFOF',
#   'GIII',
#   'GILD',
#   'GIS',
#   'GLP',
#   'GLUU',
#   'GLW',
#   'GM',
#   'GME',
#   'GMED',
#   'GNC',
#   'GNMK',
#   'GNTX',
#   'GNW',
#   'GOGO',
#   'GOOGL',
#   'GPI',
#   'GPK',
#   'GPOR',
#   'GPRE',
#   'GPRO',
#   'GPS',
#   'GPX',
#   'GRA',
#   'GRMN',
#   'GRRB',
#   'GRUB',
#   'GS',
#   'GSAT',
#   'GSBC',
#   'GT',
#   'GTT',
#   'GVA',
#   'GWB',
#   'GWRE',
#   'GWW',
#   'H',
#   'HAE',
#   'HAL',
#   'HAS',
#   'HBCP',
#   'HBI',
#   'HBNC',
#   'HBP',
#   'HCA',
#   'HCCI',
#   'HCI',
#   'HD',
#   'HDS',
#   'HEES',
#   'HEI',
#   'HELE',
#   'HES',
#   'HGPI',
#   'HGV',
#   'HHC',
#   'HHER',
#   'HHS',
#   'HII',
#   'HIL',
#   'HLI',
#   'HLT',
#   'HMHC',
#   'HMN',
#   'HMST',
#   'HMSY',
#   'HNGR',
#   'HNI',
#   'HOG',
#   'HOLX',
#   'HON',
#   'HPE',
#   'HPQ',
#   'HQY',
#   'HR',
#   'HRB',
#   'HRL',
#   'HSC',
#   'HSIC',
#   'HSTM',
#   'HTBI',
#   'HTH',
#   'HTLD',
#   'HTLF',
#   'HTZ',
#   'HUBB',
#   'HUBG',
#   'HUBS',
#   'HUM',
#   'HUN',
#   'HURN',
#   'HWKN',
#   'HXL',
#   'HZN',
#   'HZNP',
#   'HZO',
#   'IART',
#   'IBKC',
#   'IBM',
#   'IBP',
#   'ICE',
#   'ICFI',
#   'ICPT',
#   'ICUI',
#   'IDCC',
#   'IDT',
#   'IEC',
#   'IEP',
#   'IEX',
#   'IFF',
#   'IHG',
#   'III',
#   'IIVI',
#   'ILMN',
#   'IMKTA',
#   'IMMR',
#   'IMMU',
#   'INBK',
#   'INCY',
#   'INDB',
#   'INFN',
#   'INGN',
#   'INGR',
#   'INOV',
#   'INSG',
#   'INT',
#   'INTC',
#   'INTL',
#   'INTU',
#   'INVH',
#   'IP',
#   'IPGP',
#   'IPHI',
#   'IPI',
#   'IR',
#   'IRBT',
#   'IRM',
#   'IRWD',
#   'ISBC',
#   'ISRG',
#   'IT',
#   'ITIC',
#   'IVZ',
#   'JACK',
#   'JBHT',
#   'JBL',
#   'JBLU',
#   'JBSS',
#   'JBT',
#   'JCI',
#   'JJSF',
#   'JNCE',
#   'JNJ',
#   'JNPR',
#   'JPM',
#   'JWN',
#   'K',
#   'KALU',
#   'KAR',
#   'KBAL',
#   'KBH',
#   'KBR',
#   'KDP',
#   'KEX',
#   'KEYS',
#   'KFRC',
#   'KGHI',
#   'KIM',
#   'KIRK',
#   'KLAC',
#   'KMB',
#   'KMI',
#   'KMPR',
#   'KMT',
#   'KMX',
#   'KNL',
#   'KNX',
#   'KRC',
#   'KSS',
#   'KTOS',
#   'L',
#   'LAD',
#   'LAMR',
#   'LARK',
#   'LAUR',
#   'LAWS',
#   'LB',
#   'LBAI',
#   'LC',
#   'LCI',
#   'LCUT',
#   'LDOS',
#   'LE',
#   'LEA',
#   'LECO',
#   'LEE',
#   'LEG',
#   'LEN',
#   'LGIH',
#   'LHCG',
#   'LHX',
#   'LIND',
#   'LKQ',
#   'LL',
#   'LLY',
#   'LMT',
#   'LNN',
#   'LOB',
#   'LOCMQ',
#   'LOCO',
#   'LOV',
#   'LOW',
#   'LPLA',
#   'LPSN',
#   'LQDT',
#   'LRCX',
#   'LRN',
#   'LSI',
#   'LSTR',
#   'LUNA',
#   'LUV',
#   'LUVU',
#   'LVS',
#   'LW',
#   'LYB',
#   'LYTS',
#   'LYV',
#   'LZB',
#   'M',
#   'MA',
#   'MAN',
#   'MANH',
#   'MANT',
#   'MAR',
#   'MAS',
#   'MASI',
#   'MAT',
#   'MATW',
#   'MBII',
#   'MCBC',
#   'MCD',
#   'MCHP',
#   'MCHX',
#   'MCK',
#   'MCS',
#   'MD',
#   'MDB',
#   'MDLZ',
#   'MDRX',
#   'MDT',
#   'MDXG',
#   'MEDP',
#   'MERR',
#   'MET',
#   'MG',
#   'MGLN',
#   'MGM',
#   'MHGU',
#   'MHH',
#   'MHK',
#   'MHO',
#   'MIK',
#   'MINI',
#   'MKC',
#   'MKL',
#   'MKSI',
#   'MLM',
#   'MMC',
#   'MMI',
#   'MMM',
#   'MMS',
#   'MMSI',
#   'MNK',
#   'MNTA',
#   'MO',
#   'MOD',
#   'MOFG',
#   'MOH',
#   'MORN',
#   'MOS',
#   'MOV',
#   'MPB',
#   'MPC',
#   'MRC',
#   'MRCY',
#   'MRK',
#   'MRTN',
#   'MS',
#   'MSA',
#   'MSBI',
#   'MSCI',
#   'MSFT',
#   'MSI',
#   'MSM',
#   'MSTR',
#   'MTB',
#   'MTD',
#   'MTEM',
#   'MTH',
#   'MTN',
#   'MTOR',
#   'MTRN',
#   'MTRX',
#   'MTSC',
#   'MTZ',
#   'MWA',
#   'MXIM',
#   'MXL',
#   'MYGN',
#   'MYL',
#   'MYRG',
#   'NATI',
#   'NAV',
#   'NAVI',
#   'NBEV',
#   'NBL',
#   'NBTB',
#   'NCMI',
#   'NCR',
#   'NDAQ',
#   'NDLS',
#   'NDSN',
#   'NEE',
#   'NEO',
#   'NEOG',
#   'NEOS',
#   'NEWR',
#   'NEWT',
#   'NFG',
#   'NFLX',
#   'NGHC',
#   'NGVC',
#   'NGVT',
#   'NH',
#   'NHC',
#   'NI',
#   'NJR',
#   'NK',
#   'NKE',
#   'NNI',
#   'NOC',
#   'NOV',
#   'NOVT',
#   'NOW',
#   'NPO',
#   'NPTN',
#   'NRG',
#   'NSC',
#   'NSIT',
#   'NSP',
#   'NSRGY',
#   'NSTG',
#   'NTAP',
#   'NTNX',
#   'NTRS',
#   'NUS',
#   'NUVA',
#   'NVDA',
#   'NVEE',
#   'NVR',
#   'NVRO',
#   'NVTA',
#   'NWL',
#   'NWPX',
#   'NWSA',
#   'NX',
#   'NYT',
#   'OC',
#   'OCFC',
#   'ODC',
#   'ODFL',
#   'ODP',
#   'OGS',
#   'OI',
#   'OII',
#   'OIS',
#   'OKE',
#   'OKTA',
#   'OLN',
#   'OMCL',
#   'OMF',
#   'OMI',
#   'ORCL',
#   'ORLY',
#   'OSIS',
#   'OSK',
#   'OUT',
#   'OXY',
#   'PAA',
#   'PAG',
#   'PANW',
#   'PARR',
#   'PATK',
#   'PAYX',
#   'PBCT',
#   'PBF',
#   'PBI',
#   'PCAR',
#   'PCG',
#   'PCRX',
#   'PCTI',
#   'PDCO',
#   'PEBO',
#   'PEGA',
#   'PENN',
#   'PEP',
#   'PETQ',
#   'PFE',
#   'PFG',
#   'PFGC',
#   'PFPT',
#   'PFSI',
#   'PFSW',
#   'PGNT',
#   'PGR',
#   'PH',
#   'PHM',
#   'PI',
#   'PII',
#   'PK',
#   'PKG',
#   'PKI',
#   'PLAY',
#   'PLCE',
#   'PLNT',
#   'PLUS',
#   'PLXS',
#   'PMTS',
#   'PNC',
#   'PNR',
#   'PODD',
#   'POR',
#   'POWI',
#   'PPL',
#   'PRAA',
#   'PRAH',
#   'PRFT',
#   'PRGO',
#   'PRGS',
#   'PRIM',
#   'PRK',
#   'PRSP',
#   'PRU',
#   'PSA',
#   'PSMT',
#   'PSTG',
#   'PSX',
#   'PTC',
#   'PTCT',
#   'PTSI',
#   'PVBC',
#   'PVH',
#   'PWR',
#   'PYPL',
#   'PZZA',
#   'QADA',
#   'QCCO',
#   'QCOM',
#   'QDEL',
#   'QLYS',
#   'QRVO',
#   'QSR',
#   'QUOT',
#   'R',
#   'RAD',
#   'RARE',
#   'RAVN',
#   'RBC',
#   'RCII',
#   'RCL',
#   'RCM',
#   'RDN',
#   'RDUS',
#   'REGI',
#   'REV',
#   'REVG',
#   'REXR',
#   'RF',
#   'RGNX',
#   'RGS',
#   'RHI',
#   'RJF',
#   'RL',
#   'RLGY',
#   'RLH',
#   'RLI',
#   ...],
#  '2019-11': ['A',
#   'AA',
#   'AAL',
#   'AAN',
#   'AAP',
#   'AAWW',
#   'AB',
#   'ABBV',
#   'ABC',
#   'ABCB',
#   'ABG',
#   'ABM',
#   'ABMD',
#   'ABT',
#   'ACAD',
#   'ACC',
#   'ACCO',
#   'ACHC',
#   'ACIA',
#   'ACIW',
#   'ACLS',
#   'ACN',
#   'ADBE',
#   'ADDDF',
#   'ADI',
#   'ADM',
#   'ADMA',
#   'ADP',
#   'ADS',
#   'ADSK',
#   'ADSW',
#   'ADT',
#   'ADTN',
#   'ADUS',
#   'AEE',
#   'AEIS',
#   'AEO',
#   'AEP',
#   'AES',
#   'AFG',
#   'AFI',
#   'AFL',
#   'AGCO',
#   'AGIO',
#   'AGYS',
#   'AIMC',
#   'AIMT',
#   'AIR',
#   'AIT',
#   'AIZ',
#   'AJRD',
#   'AKAM',
#   'AKBA',
#   'AKCA',
#   'ALB',
#   'ALG',
#   'ALGN',
#   'ALGT',
#   'ALL',
#   'ALLE',
#   'ALLY',
#   'ALRM',
#   'ALRS',
#   'ALSN',
#   'ALTR',
#   'ALXN',
#   'AMAG',
#   'AMAT',
#   'AMBK',
#   'AMD',
#   'AME',
#   'AMED',
#   'AMGN',
#   'AMH',
#   'AMNB',
#   'AMP',
#   'AMRS',
#   'AMSC',
#   'AMSF',
#   'AMT',
#   'AMTD',
#   'AMWD',
#   'AMZN',
#   'AN',
#   'ANAB',
#   'ANAT',
#   'ANDE',
#   'ANET',
#   'ANF',
#   'ANIK',
#   'ANSS',
#   'ANTM',
#   'AOS',
#   'APA',
#   'APD',
#   'APEI',
#   'APO',
#   'APPF',
#   'APPN',
#   'ARA',
#   'ARAY',
#   'ARC',
#   'ARCB',
#   'ARMK',
#   'AROC',
#   'ARW',
#   'ASB',
#   'ASUR',
#   'ATEN',
#   'ATGE',
#   'ATKR',
#   'ATNI',
#   'ATRA',
#   'ATRC',
#   'ATRO',
#   'ATUS',
#   'AVAV',
#   'AVB',
#   'AVGG',
#   'AVGO',
#   'AVID',
#   'AVT',
#   'AVY',
#   'AWI',
#   'AWK',
#   'AXE',
#   'AXL',
#   'AXP',
#   'AXTA',
#   'AYI',
#   'AYX',
#   'AZO',
#   'B',
#   'BA',
#   'BABA',
#   'BAC',
#   'BAH',
#   'BANC',
#   'BAND',
#   'BANF',
#   'BBBY',
#   'BBW',
#   'BBY',
#   'BC',
#   'BCO',
#   'BCOV',
#   'BCPC',
#   'BDC',
#   'BECN',
#   'BERK',
#   'BERY',
#   'BFAM',
#   'BFIN',
#   'BGCP',
#   'BGFV',
#   'BGS',
#   'BHB',
#   'BHE',
#   'BHF',
#   'BIIB',
#   'BIOQ',
#   'BJRI',
#   'BKD',
#   'BKE',
#   'BKH',
#   'BKI',
#   'BKU',
#   'BL',
#   'BLDR',
#   'BLK',
#   'BLKB',
#   'BLL',
#   'BLMN',
#   'BLUE',
#   'BMRC',
#   'BMY',
#   'BNED',
#   'BNFT',
#   'BOH',
#   'BOKF',
#   'BOOT',
#   'BOX',
#   'BPOP',
#   'BRID',
#   'BRKL',
#   'BRKR',
#   'BRKS',
#   'BRO',
#   'BSET',
#   'BSX',
#   'BTN',
#   'BV',
#   'BW',
#   'BWA',
#   'BWEN',
#   'BWXT',
#   'BXS',
#   'BY',
#   'BYD',
#   'BZH',
#   'C',
#   'CABO',
#   'CAC',
#   'CACC',
#   'CADE',
#   'CAG',
#   'CAH',
#   'CAKE',
#   'CAL',
#   'CALB',
#   'CALX',
#   'CAMP',
#   'CAPC',
#   'CAR',
#   'CARG',
#   'CARS',
#   'CASY',
#   'CAT',
#   'CATO',
#   'CB',
#   'CBB',
#   'CBOE',
#   'CBRE',
#   'CBRL',
#   'CBSH',
#   'CBU',
#   'CBZ',
#   'CC',
#   'CCBG',
#   'CCI',
#   'CCL',
#   'CCMP',
#   'CCNE',
#   'CCO',
#   'CCOI',
#   'CCRN',
#   'CCS',
#   'CDK',
#   'CDNA',
#   'CDNS',
#   'CE',
#   'CELP',
#   'CENT',
#   'CERN',
#   'CEVA',
#   'CF',
#   'CFFN',
#   'CG',
#   'CGNX',
#   'CHD',
#   'CHEF',
#   'CHGG',
#   'CHH',
#   'CHRS',
#   'CHRW',
#   'CHS',
#   'CHSCO',
#   'CHUY',
#   'CI',
#   'CIEN',
#   'CIR',
#   'CIT',
#   'CL',
#   'CLAR',
#   'CLCN',
#   'CLDR',
#   'CLFD',
#   'CLGX',
#   'CLH',
#   'CLI',
#   'CLR',
#   'CLUB',
#   'CLW',
#   'CLX',
#   'CLXT',
#   'CMA',
#   'CMC',
#   'CMCO',
#   'CMD',
#   'CME',
#   'CMG',
#   'CMI',
#   'CMLS',
#   'CMP',
#   'CMTL',
#   'CMTV',
#   'CNBKA',
#   'CNC',
#   'CNDT',
#   'CNMD',
#   'CNOB',
#   'CNP',
#   'CNS',
#   'CNSL',
#   'COF',
#   'COHR',
#   'COLB',
#   'COLL',
#   'COLM',
#   'CONE',
#   'CONN',
#   'COO',
#   'COP',
#   'COST',
#   'COTY',
#   'CPB',
#   'CPIX',
#   'CPK',
#   'CPS',
#   'CPSS',
#   'CR',
#   'CREE',
#   'CRHCF',
#   'CRI',
#   'CRLKP',
#   'CRMT',
#   'CROX',
#   'CRS',
#   'CRUS',
#   'CSGP',
#   'CSII',
#   'CSL',
#   'CSLT',
#   'CSOD',
#   'CSU',
#   'CSV',
#   'CSX',
#   'CTAS',
#   'CTB',
#   'CTBI',
#   'CTEK',
#   'CTL',
#   'CTLT',
#   'CTRN',
#   'CTS',
#   'CTSH',
#   'CUB',
#   'CUBI',
#   'CUTR',
#   'CVCY',
#   'CVGI',
#   'CVI',
#   'CVS',
#   'CVT',
#   'CVTI',
#   'CVX',
#   'CW',
#   'CWH',
#   'CWST',
#   'CWT',
#   'CXW',
#   'CYH',
#   'CZBS',
#   'CZR',
#   'D',
#   'DAKT',
#   'DAL',
#   'DAN',
#   'DBD',
#   'DCI',
#   'DCO',
#   'DCP',
#   'DDD',
#   'DDS',
#   'DE',
#   'DELL',
#   'DENN',
#   'DFIN',
#   'DFS',
#   'DG',
#   'DGX',
#   'DHI',
#   'DIS',
#   'DISCA',
#   'DISH',
#   'DLTR',
#   'DLX',
#   'DMRC',
#   'DNKN',
#   'DOOR',
#   'DORM',
#   'DOV',
#   'DOW',
#   'DPSGY',
#   'DPZ',
#   'DRAD',
#   'DRI',
#   'DRNA',
#   'DTE',
#   'DUK',
#   'DVCR',
#   'DXC',
#   'DXCM',
#   'DXPE',
#   'EA',
#   'EAT',
#   'EBAY',
#   'EBS',
#   'EBTC',
#   'ECHO',
#   'ECL',
#   'ECOL',
#   'EEFT',
#   'EEX',
#   'EFX',
#   'EGBN',
#   'EGHT',
#   'EGOV',
#   'EGRX',
#   'EHC',
#   'EHTH',
#   'EIG',
#   'EIGI',
#   'EIX',
#   'EL',
#   'ELS',
#   'EME',
#   'EMR',
#   'ENBL',
#   'ENG',
#   'ENLC',
#   'ENPH',
#   'ENR',
#   'ENS',
#   'ENTG',
#   'ENVA',
#   'EPAM',
#   'EPC',
#   'EQIX',
#   'EQR',
#   'ESS',
#   'ETEC',
#   'ETFC',
#   'ETM',
#   'ETN',
#   'ETR',
#   'ETSY',
#   'EV',
#   'EVBG',
#   'EVBN',
#   'EVC',
#   'EVH',
#   'EW',
#   'EWBC',
#   'EXAS',
#   'EXC',
#   'EXEL',
#   'EXLS',
#   'EXPO',
#   'EXPR',
#   'EXR',
#   'EXTR',
#   'EYE',
#   'F',
#   'FARO',
#   'FAST',
#   'FB',
#   'FBAK',
#   'FBC',
#   'FBM',
#   'FBNC',
#   'FC',
#   'FCBC',
#   'FCF',
#   'FCFS',
#   'FCN',
#   'FCX',
#   'FDX',
#   'FELE',
#   'FET',
#   'FFBC',
#   'FFIN',
#   'FGEN',
#   'FHB',
#   'FIBK',
#   'FIEB',
#   'FISV',
#   'FIT',
#   'FIVE',
#   'FIVN',
#   'FIZZ',
#   'FL',
#   'FLIR',
#   'FLOW',
#   'FLR',
#   'FLS',
#   'FLWS',
#   'FLXN',
#   'FLXS',
#   'FMBI',
#   'FMCB',
#   'FMCC',
#   'FMNB',
#   'FNB',
#   'FND',
#   'FNF',
#   'FNKO',
#   'FNWB',
#   'FOE',
#   'FORM',
#   'FORR',
#   'FOSL',
#   'FOXF',
#   'FPCG',
#   'FRAN',
#   'FRME',
#   'FRPT',
#   'FRTA',
#   'FSS',
#   'FSTR',
#   'FTLF',
#   'FTNT',
#   'FUL',
#   'FULT',
#   'FUNC',
#   'FVE',
#   'FWRD',
#   'GABC',
#   'GBCI',
#   'GBL',
#   'GBT',
#   'GCI',
#   'GCO',
#   'GD',
#   'GDDY',
#   'GDEN',
#   'GDOT',
#   'GE',
#   'GEF',
#   'GEO',
#   'GES',
#   'GFNL',
#   'GGG',
#   'GIB',
#   'GIFOF',
#   'GIII',
#   'GILD',
#   'GIS',
#   'GLP',
#   'GLUU',
#   'GLW',
#   'GM',
#   'GME',
#   'GMED',
#   'GNC',
#   'GNMK',
#   'GNTX',
#   'GNW',
#   'GOOGL',
#   'GPI',
#   'GPK',
#   'GPN',
#   'GPRE',
#   'GPRO',
#   'GPS',
#   'GPX',
#   'GRA',
#   'GRMN',
#   'GRUB',
#   'GRWG',
#   'GS',
#   'GSBC',
#   'GTLS',
#   'GTT',
#   'GVA',
#   'GWB',
#   'GWRE',
#   'H',
#   'HAE',
#   'HAL',
#   'HBI',
#   'HBNC',
#   'HBP',
#   'HCA',
#   'HCCI',
#   'HCSG',
#   'HD',
#   'HDS',
#   'HEES',
#   'HEI',
#   'HELE',
#   'HES',
#   'HGV',
#   'HHC',
#   'HHS',
#   'HI',
#   'HIBB',
#   'HII',
#   'HIL',
#   'HLI',
#   'HLNE',
#   'HLT',
#   'HMHC',
#   'HMN',
#   'HMST',
#   'HNGR',
#   'HNI',
#   'HOFT',
#   'HOG',
#   'HOLX',
#   'HON',
#   'HPE',
#   'HPP',
#   'HPQ',
#   'HQY',
#   'HR',
#   'HRB',
#   'HSC',
#   'HSTM',
#   'HSY',
#   'HTH',
#   'HTLF',
#   'HTZ',
#   'HUBB',
#   'HUBS',
#   'HUM',
#   'HUN',
#   'HVT',
#   'HWKN',
#   'HXL',
#   'HY',
#   'HZN',
#   'HZNP',
#   'HZO',
#   'IART',
#   'IBKC',
#   'IBM',
#   'IBP',
#   'ICCH',
#   'ICE',
#   'ICFI',
#   'ICPT',
#   'ICUI',
#   'IDCC',
#   'IDT',
#   'IEC',
#   'IEP',
#   'IESC',
#   'IEX',
#   'IFF',
#   'IHG',
#   'III',
#   'IIN',
#   'IIVI',
#   'ILMN',
#   'IMAX',
#   'IMKTA',
#   'IMMU',
#   'INCY',
#   'INDB',
#   'INFN',
#   'INGN',
#   'INGR',
#   'INOV',
#   'INSG',
#   'INSM',
#   'INT',
#   'INTC',
#   'INTL',
#   'INVH',
#   'IONS',
#   'IP',
#   'IRBT',
#   'IRM',
#   'ISBC',
#   'ISDR',
#   'ISIG',
#   'ISRG',
#   'IT',
#   'ITI',
#   'ITIC',
#   'ITRI',
#   'IVC',
#   'IVZ',
#   'IZEA',
#   'JACK',
#   'JBHT',
#   'JBLU',
#   'JBT',
#   'JKHY',
#   'JNCE',
#   'JNJ',
#   'JNPR',
#   'JPM',
#   'JWN',
#   'K',
#   'KAR',
#   'KBAL',
#   'KBH',
#   'KBR',
#   'KEYS',
#   'KFRC',
#   'KGHI',
#   'KHC',
#   'KIM',
#   'KIRK',
#   'KLAC',
#   'KLIC',
#   'KMI',
#   'KMPR',
#   'KMT',
#   'KMX',
#   'KNX',
#   'KO',
#   'KR',
#   'KRC',
#   'KSS',
#   'KSU',
#   'KTOS',
#   'KTYB',
#   'L',
#   'LAD',
#   'LAMR',
#   'LARK',
#   'LAUR',
#   'LAWS',
#   'LB',
#   'LBAI',
#   'LC',
#   'LDOS',
#   'LE',
#   'LECO',
#   'LEE',
#   'LEG',
#   'LEN',
#   'LEU',
#   'LGIH',
#   'LHCG',
#   'LHX',
#   'LIND',
#   'LKQ',
#   'LL',
#   'LMNX',
#   'LMT',
#   'LNN',
#   'LNT',
#   'LOB',
#   'LOCMQ',
#   'LOCO',
#   'LOGM',
#   'LOW',
#   'LPTH',
#   'LQDT',
#   'LRCX',
#   'LRN',
#   'LSI',
#   'LSTR',
#   'LTRE',
#   'LTTC',
#   'LUNA',
#   'LVS',
#   'LW',
#   'LYB',
#   'LYV',
#   'LZB',
#   'M',
#   'MA',
#   'MAN',
#   'MANH',
#   'MAR',
#   'MAS',
#   'MASI',
#   'MAT',
#   'MATW',
#   'MCD',
#   'MCHP',
#   'MCHX',
#   'MCK',
#   'MCS',
#   'MD',
#   'MDB',
#   'MDLZ',
#   'MDP',
#   'MDRX',
#   'MDT',
#   'MDXG',
#   'MED',
#   'MEDP',
#   'MEI',
#   'MET',
#   'MG',
#   'MGLN',
#   'MGM',
#   'MGRC',
#   'MHK',
#   'MHO',
#   'MIK',
#   'MINI',
#   'MKL',
#   'MKSI',
#   'MLHR',
#   'MLM',
#   'MLR',
#   'MMC',
#   'MMI',
#   'MMM',
#   'MMP',
#   'MMS',
#   'MMSI',
#   'MN',
#   'MNK',
#   'MNRO',
#   'MOBL',
#   'MOFG',
#   'MOH',
#   'MORN',
#   'MOS',
#   'MOV',
#   'MPC',
#   'MRC',
#   'MRCY',
#   'MRK',
#   'MS',
#   'MSA',
#   'MSBI',
#   'MSCI',
#   'MSFT',
#   'MSI',
#   'MSM',
#   'MSTR',
#   'MTB',
#   'MTD',
#   'MTH',
#   'MTN',
#   'MTOR',
#   'MTRN',
#   'MTRX',
#   'MTSC',
#   'MTZ',
#   'MWA',
#   'MXIM',
#   'MXL',
#   'MYGN',
#   'MYL',
#   'MYOK',
#   'MYRG',
#   'NATI',
#   'NAV',
#   'NAVI',
#   'NBL',
#   'NBTB',
#   'NCMI',
#   'NCR',
#   'NDAQ',
#   'NDLS',
#   'NDSN',
#   'NEE',
#   'NEM',
#   'NEO',
#   'NEOG',
#   'NEOS',
#   'NEWR',
#   'NEWT',
#   'NFBK',
#   'NFLX',
#   'NGHC',
#   'NGVC',
#   'NGVT',
#   'NH',
#   'NHC',
#   'NI',
#   'NJR',
#   'NK',
#   'NKE',
#   'NLS',
#   'NNI',
#   'NOC',
#   'NOV',
#   'NOVT',
#   'NOW',
#   'NP',
#   'NPO',
#   'NRG',
#   'NS',
#   'NSC',
#   'NSIT',
#   'NSP',
#   'NSRGY',
#   'NSTG',
#   'NTAP',
#   'NTGR',
#   'NTNX',
#   'NTRA',
#   'NTRS',
#   'NUS',
#   'NUVA',
#   'NVDA',
#   'NVEC',
#   'NVEE',
#   'NVR',
#   'NVTA',
#   'NWL',
#   'NWPX',
#   'NWSA',
#   'NX',
#   'NYT',
#   'OC',
#   'OCFC',
#   'OCUL',
#   'ODC',
#   'ODFL',
#   'ODP',
#   'OGE',
#   'OGS',
#   'OI',
#   'OII',
#   'OIS',
#   'OKE',
#   'OKTA',
#   'OLBK',
#   'OLLI',
#   'OLN',
#   'OMCL',
#   'OMF',
#   'OMI',
#   'OOMA',
#   'OPOF',
#   'ORA',
#   'ORBC',
#   'ORCL',
#   'ORN',
#   'OSK',
#   'OUT',
#   'OXY',
#   'PAA',
#   'PAG',
#   'PANW',
#   'PARR',
#   'PAYX',
#   'PB',
#   'PBCT',
#   'PBF',
#   'PBI',
#   'PCAR',
#   'PCG',
#   'PDCO',
#   'PE',
#   'PEBO',
#   'PEGA',
#   'PENN',
#   'PEP',
#   'PFE',
#   'PFG',
#   'PFGC',
#   'PFPT',
#   'PFSI',
#   'PFSW',
#   'PGNT',
#   'PGR',
#   'PH',
#   'PHM',
#   'PI',
#   'PII',
#   'PINC',
#   'PK',
#   'PKG',
#   'PKI',
#   'PLAY',
#   'PLCE',
#   'PLD',
#   'PLUG',
#   'PLXS',
#   'PMTS',
#   'PNC',
#   'PNM',
#   'PNR',
#   'PODD',
#   'POR',
#   'POWI',
#   'PPBI',
#   'PPL',
#   'PRAA',
#   'PRAH',
#   'PRFT',
#   'PRGS',
#   'PRGX',
#   'PRIM',
#   'PRK',
#   'PRSP',
#   'PRU',
#   'PSA',
#   'PSTG',
#   'PSX',
#   'PTC',
#   'PTCT',
#   'PTSI',
#   'PVBC',
#   'PVH',
#   'PWR',
#   'PXD',
#   'PYPL',
#   'PZZA',
#   'QADA',
#   'QCOM',
#   'QDEL',
#   'QLYS',
#   'QNST',
#   'QRVO',
#   'QUOT',
#   'R',
#   ...],
#  '2019-12': ['A',
#   'AA',
#   'AAL',
#   'AAN',
#   'AAOI',
#   'AAP',
#   'AAWW',
#   'AB',
#   'ABBV',
#   'ABC',
#   'ABG',
#   'ABM',
#   'ABMC',
#   'ABMD',
#   'ABT',
#   'ACAD',
#   'ACBI',
#   'ACC',
#   'ACCO',
#   'ACHC',
#   'ACIA',
#   'ACIW',
#   'ACLS',
#   'ACN',
#   'ADBE',
#   'ADDDF',
#   'ADI',
#   'ADM',
#   'ADP',
#   'ADS',
#   'ADSK',
#   'ADSW',
#   'ADT',
#   'ADUS',
#   'AEE',
#   'AEIS',
#   'AEO',
#   'AEP',
#   'AES',
#   'AFG',
#   'AFI',
#   'AFL',
#   'AGCO',
#   'AGIO',
#   'AGYS',
#   'AHH',
#   'AIMC',
#   'AIN',
#   'AIR',
#   'AIRG',
#   'AIT',
#   'AIZ',
#   'AJRD',
#   'AKAM',
#   'AKBA',
#   'AKCA',
#   'AKTS',
#   'ALB',
#   'ALBO',
#   'ALG',
#   'ALGN',
#   'ALGT',
#   'ALL',
#   'ALLE',
#   'ALLY',
#   'ALRM',
#   'ALRS',
#   'ALSN',
#   'ALTR',
#   'ALV',
#   'ALXN',
#   'ALYE',
#   'AMAG',
#   'AMAT',
#   'AMBA',
#   'AMD',
#   'AME',
#   'AMED',
#   'AMGN',
#   'AMH',
#   'AMKR',
#   'AMNB',
#   'AMP',
#   'AMRC',
#   'AMRS',
#   'AMSC',
#   'AMSF',
#   'AMT',
#   'AMTD',
#   'AMWD',
#   'AN',
#   'ANAB',
#   'ANAT',
#   'ANDE',
#   'ANF',
#   'ANGO',
#   'ANIK',
#   'ANSS',
#   'ANTM',
#   'AON',
#   'AOS',
#   'AP',
#   'APA',
#   'APAM',
#   'APD',
#   'APEI',
#   'APPF',
#   'APPN',
#   'APRN',
#   'AQUA',
#   'ARA',
#   'ARAY',
#   'ARC',
#   'ARCB',
#   'ARCH',
#   'ARDX',
#   'ARLP',
#   'ARMK',
#   'AROC',
#   'ARW',
#   'ASB',
#   'ASBN',
#   'ASH',
#   'ASNA',
#   'ASUR',
#   'ATGE',
#   'ATKR',
#   'ATNX',
#   'ATO',
#   'ATRA',
#   'ATRC',
#   'ATRO',
#   'ATUS',
#   'AVA',
#   'AVAV',
#   'AVB',
#   'AVGO',
#   'AVID',
#   'AVT',
#   'AVY',
#   'AWI',
#   'AWK',
#   'AWRE',
#   'AXDX',
#   'AXE',
#   'AXL',
#   'AXP',
#   'AYI',
#   'AYX',
#   'AZO',
#   'AZPN',
#   'B',
#   'BA',
#   'BABA',
#   'BAC',
#   'BAH',
#   'BANC',
#   'BAND',
#   'BANF',
#   'BAX',
#   'BBBK',
#   'BBBY',
#   'BBW',
#   'BBY',
#   'BC',
#   'BCC',
#   'BCO',
#   'BCOV',
#   'BCPC',
#   'BDC',
#   'BEAT',
#   'BECN',
#   'BERK',
#   'BERY',
#   'BFAM',
#   'BFIN',
#   'BGCP',
#   'BGFV',
#   'BHB',
#   'BHE',
#   'BHF',
#   'BHWB',
#   'BIG',
#   'BIIB',
#   'BJRI',
#   'BKD',
#   'BKE',
#   'BKH',
#   'BKI',
#   'BKU',
#   'BL',
#   'BLD',
#   'BLDR',
#   'BLK',
#   'BLKB',
#   'BLL',
#   'BLMN',
#   'BLUE',
#   'BMI',
#   'BMRC',
#   'BMY',
#   'BNED',
#   'BNFT',
#   'BOH',
#   'BOKF',
#   'BOOT',
#   'BOX',
#   'BPMC',
#   'BPOP',
#   'BPRN',
#   'BRC',
#   'BRKL',
#   'BRKR',
#   'BRKS',
#   'BRO',
#   'BSET',
#   'BSX',
#   'BV',
#   'BW',
#   'BWA',
#   'BWEN',
#   'BWXT',
#   'BXP',
#   'BXS',
#   'BY',
#   'BYD',
#   'BZH',
#   'C',
#   'CABO',
#   'CAC',
#   'CACC',
#   'CACI',
#   'CADE',
#   'CAG',
#   'CAH',
#   'CAKE',
#   'CAL',
#   'CALB',
#   'CALX',
#   'CAMP',
#   'CAPC',
#   'CAR',
#   'CARG',
#   'CARS',
#   'CAT',
#   'CATM',
#   'CATO',
#   'CATS',
#   'CB',
#   'CBB',
#   'CBL',
#   'CBRE',
#   'CBRL',
#   'CBSH',
#   'CBT',
#   'CBU',
#   'CBZ',
#   'CC',
#   'CCEL',
#   'CCF',
#   'CCI',
#   'CCL',
#   'CCLP',
#   'CCMP',
#   'CCNE',
#   'CCO',
#   'CCOI',
#   'CCRN',
#   'CCS',
#   'CCXI',
#   'CDK',
#   'CDNA',
#   'CDNS',
#   'CE',
#   'CEIX',
#   'CELP',
#   'CENT',
#   'CERN',
#   'CEVA',
#   'CF',
#   'CFMS',
#   'CFOK',
#   'CG',
#   'CHD',
#   'CHDN',
#   'CHEF',
#   'CHGG',
#   'CHH',
#   'CHRS',
#   'CHRW',
#   'CHS',
#   'CHSCO',
#   'CHUY',
#   'CI',
#   'CIA',
#   'CIEN',
#   'CIR',
#   'CIWV',
#   'CKH',
#   'CL',
#   'CLAR',
#   'CLCN',
#   'CLDR',
#   'CLFD',
#   'CLGX',
#   'CLH',
#   'CLR',
#   'CLW',
#   'CLX',
#   'CMA',
#   'CMC',
#   'CMCO',
#   'CMCSA',
#   'CMD',
#   'CME',
#   'CMG',
#   'CMI',
#   'CMLS',
#   'CMP',
#   'CMTL',
#   'CNC',
#   'CNDT',
#   'CNMD',
#   'CNND',
#   'CNOB',
#   'CNP',
#   'CNR',
#   'CNSL',
#   'CNXS',
#   'COF',
#   'COHN',
#   'COHR',
#   'COKE',
#   'COLB',
#   'COLM',
#   'CONN',
#   'COO',
#   'COP',
#   'COST',
#   'COTY',
#   'CPB',
#   'CPRT',
#   'CPS',
#   'CPSS',
#   'CR',
#   'CRBP',
#   'CREE',
#   'CRHCF',
#   'CRI',
#   'CRLKP',
#   'CRMT',
#   'CRMZ',
#   'CROX',
#   'CRS',
#   'CRSP',
#   'CRUS',
#   'CRWS',
#   'CRY',
#   'CSBR',
#   'CSCO',
#   'CSGP',
#   'CSII',
#   'CSL',
#   'CSLT',
#   'CSOD',
#   'CSPI',
#   'CSU',
#   'CSV',
#   'CSVI',
#   'CSX',
#   'CTAS',
#   'CTB',
#   'CTEK',
#   'CTL',
#   'CTLT',
#   'CTMX',
#   'CTRN',
#   'CTSH',
#   'CUB',
#   'CUBI',
#   'CUTR',
#   'CVCO',
#   'CVCY',
#   'CVEO',
#   'CVS',
#   'CVT',
#   'CVTI',
#   'CVX',
#   'CW',
#   'CWH',
#   'CWST',
#   'CWT',
#   'CXW',
#   'CYBE',
#   'CYH',
#   'CZBS',
#   'CZR',
#   'CZWI',
#   'D',
#   'DAKT',
#   'DAL',
#   'DAN',
#   'DAR',
#   'DBD',
#   'DCI',
#   'DCO',
#   'DCOM',
#   'DCP',
#   'DDD',
#   'DDS',
#   'DE',
#   'DECK',
#   'DELL',
#   'DENN',
#   'DFIN',
#   'DFS',
#   'DG',
#   'DGX',
#   'DHI',
#   'DHX',
#   'DIN',
#   'DIS',
#   'DISCA',
#   'DISH',
#   'DLTR',
#   'DLX',
#   'DNKN',
#   'DOOR',
#   'DORM',
#   'DOV',
#   'DOW',
#   'DPSGY',
#   'DPZ',
#   'DRAD',
#   'DRI',
#   'DS',
#   'DTE',
#   'DUK',
#   'DUOT',
#   'DVA',
#   'DVCR',
#   'DXC',
#   'DXCM',
#   'DXLG',
#   'DXPE',
#   'DXYN',
#   'EA',
#   'EAT',
#   'EBAY',
#   'EBIX',
#   'EBS',
#   'EBTC',
#   'ECHO',
#   'ECL',
#   'ECOL',
#   'EDIT',
#   'EE',
#   'EEX',
#   'EFX',
#   'EGBN',
#   'EGHT',
#   'EGOV',
#   'EHC',
#   'EHTH',
#   'EIG',
#   'EIGI',
#   'EIX',
#   'EL',
#   'ELS',
#   'EME',
#   'EML',
#   'EMMS',
#   'EMPR',
#   'EMR',
#   'ENBL',
#   'ENLC',
#   'ENPH',
#   'ENR',
#   'ENS',
#   'ENTG',
#   'ENVA',
#   'EPAM',
#   'EPAY',
#   'EPC',
#   'EQIX',
#   'EQR',
#   'EQT',
#   'ERII',
#   'ESBK',
#   'ESS',
#   'ETFC',
#   'ETH',
#   'ETM',
#   'ETN',
#   'ETR',
#   'ETSY',
#   'EUOT',
#   'EVBG',
#   'EVBN',
#   'EVH',
#   'EW',
#   'EWBC',
#   'EXAS',
#   'EXC',
#   'EXEL',
#   'EXLS',
#   'EXPO',
#   'EXPR',
#   'EXR',
#   'EXTR',
#   'EYE',
#   'F',
#   'FAST',
#   'FB',
#   'FBAK',
#   'FBC',
#   'FBM',
#   'FBNC',
#   'FC',
#   'FCBC',
#   'FCF',
#   'FCFS',
#   'FCN',
#   'FCX',
#   'FDX',
#   'FEIM',
#   'FELE',
#   'FET',
#   'FFBC',
#   'FFIN',
#   'FHB',
#   'FIBK',
#   'FISV',
#   'FIT',
#   'FIVE',
#   'FIVN',
#   'FIX',
#   'FIZZ',
#   'FL',
#   'FLDM',
#   'FLIR',
#   'FLOW',
#   'FLR',
#   'FLS',
#   'FLXN',
#   'FLXS',
#   'FMBI',
#   'FMC',
#   'FMCC',
#   'FMNB',
#   'FNB',
#   'FND',
#   'FNF',
#   'FNKO',
#   'FNWB',
#   'FOE',
#   'FORM',
#   'FORR',
#   'FOSL',
#   'FOXF',
#   'FPCG',
#   'FRAN',
#   'FRC',
#   'FRME',
#   'FRT',
#   'FRTA',
#   'FSLR',
#   'FSS',
#   'FTLF',
#   'FUL',
#   'FULT',
#   'FUNC',
#   'FVE',
#   'FWRD',
#   'GBCI',
#   'GBT',
#   'GCI',
#   'GCO',
#   'GCP',
#   'GD',
#   'GDDY',
#   'GDEN',
#   'GDOT',
#   'GE',
#   'GEF',
#   'GEN',
#   'GEO',
#   'GES',
#   'GFNL',
#   'GGG',
#   'GHC',
#   'GIB',
#   'GIFOF',
#   'GIII',
#   'GILD',
#   'GIS',
#   'GLDD',
#   'GLP',
#   'GLUU',
#   'GLW',
#   'GM',
#   'GME',
#   'GMED',
#   'GMS',
#   'GNC',
#   'GNMK',
#   'GNTX',
#   'GNW',
#   'GOGO',
#   'GOOGL',
#   'GPC',
#   'GPI',
#   'GPK',
#   'GPN',
#   'GPOR',
#   'GPRE',
#   'GPRO',
#   'GPS',
#   'GPX',
#   'GRA',
#   'GRMN',
#   'GRRB',
#   'GRUB',
#   'GS',
#   'GSBC',
#   'GTHX',
#   'GTLS',
#   'GTT',
#   'GVA',
#   'GWB',
#   'GWRE',
#   'GWW',
#   'H',
#   'HAE',
#   'HAL',
#   'HALO',
#   'HAS',
#   'HBI',
#   'HBMD',
#   'HBNC',
#   'HBP',
#   'HCA',
#   'HCCI',
#   'HCI',
#   'HCKT',
#   'HCSG',
#   'HD',
#   'HDS',
#   'HEAR',
#   'HEES',
#   'HEI',
#   'HELE',
#   'HES',
#   'HGV',
#   'HIBB',
#   'HII',
#   'HIL',
#   'HL',
#   'HLT',
#   'HMHC',
#   'HMN',
#   'HMST',
#   'HMSY',
#   'HNFSA',
#   'HNGR',
#   'HNI',
#   'HOG',
#   'HOLX',
#   'HON',
#   'HPE',
#   'HPP',
#   'HPQ',
#   'HQY',
#   'HR',
#   'HRB',
#   'HRL',
#   'HSC',
#   'HSY',
#   'HTH',
#   'HTLD',
#   'HTLF',
#   'HTZ',
#   'HUBB',
#   'HUBG',
#   'HUBS',
#   'HUM',
#   'HUN',
#   'HVT',
#   'HXL',
#   'HY',
#   'HZNP',
#   'HZO',
#   'IART',
#   'IBKC',
#   'IBM',
#   'IBOC',
#   'IBP',
#   'ICAD',
#   'ICE',
#   'ICFI',
#   'ICPT',
#   'ICUI',
#   'IDCC',
#   'IEC',
#   'IEP',
#   'IESC',
#   'IEX',
#   'IHG',
#   'III',
#   'IIN',
#   'IIVI',
#   'ILMN',
#   'IMKTA',
#   'IMMU',
#   'INCY',
#   'INDB',
#   'INFN',
#   'INGN',
#   'INGR',
#   'INO',
#   'INOV',
#   'INSG',
#   'INSM',
#   'INT',
#   'INTC',
#   'INTL',
#   'INTU',
#   'INVH',
#   'INWK',
#   'IONS',
#   'IP',
#   'IPHI',
#   'IPI',
#   'IR',
#   'IRBT',
#   'IRM',
#   'IRWD',
#   'ISBC',
#   'ISDR',
#   'ISRG',
#   'IT',
#   'ITEX',
#   'ITI',
#   'ITIC',
#   'ITRI',
#   'IVC',
#   'IVZ',
#   'IZEA',
#   'JACK',
#   'JAX',
#   'JBHT',
#   'JBL',
#   'JBLU',
#   'JBSS',
#   'JCI',
#   'JJSF',
#   'JKHY',
#   'JNCE',
#   'JNJ',
#   'JNPR',
#   'JPM',
#   'JWN',
#   'K',
#   'KALU',
#   'KAR',
#   'KBAL',
#   'KBH',
#   'KBR',
#   'KEQU',
#   'KEYS',
#   'KFRC',
#   'KGHI',
#   'KHC',
#   'KIRK',
#   'KISB',
#   'KLAC',
#   'KMB',
#   'KMI',
#   'KMPR',
#   'KMT',
#   'KMX',
#   'KNX',
#   'KO',
#   'KR',
#   'KSS',
#   'KSU',
#   'KTOS',
#   'KURA',
#   'KVHI',
#   'L',
#   'LAD',
#   'LAMR',
#   'LARK',
#   'LAUR',
#   'LAWS',
#   'LB',
#   'LC',
#   'LCI',
#   'LCUT',
#   'LDOS',
#   'LE',
#   'LEA',
#   'LECO',
#   'LEE',
#   'LEG',
#   'LEN',
#   'LEU',
#   'LFUS',
#   'LGIH',
#   'LHCG',
#   'LHX',
#   'LKQ',
#   'LL',
#   'LM',
#   'LMAT',
#   'LMNX',
#   'LMT',
#   'LNG',
#   'LNN',
#   'LOCO',
#   'LOGM',
#   'LPLA',
#   'LPSN',
#   'LQDT',
#   'LRCX',
#   'LRN',
#   'LSI',
#   'LSTR',
#   'LTNC',
#   'LTRX',
#   'LTTC',
#   'LUV',
#   'LVS',
#   'LW',
#   'LYB',
#   'LZB',
#   'M',
#   'MA',
#   'MAC',
#   'MANH',
#   'MANT',
#   'MAR',
#   'MAS',
#   'MAT',
#   'MCBC',
#   'MCD',
#   'MCHP',
#   'MCHX',
#   'MCK',
#   'MCS',
#   'MD',
#   'MDB',
#   'MDLZ',
#   'MDP',
#   'MDRX',
#   'MDT',
#   'MDU',
#   'MDXG',
#   'MEDP',
#   'MET',
#   'MG',
#   'MGLN',
#   'MGM',
#   'MGNX',
#   'MGRC',
#   'MGYR',
#   'MHGU',
#   'MHK',
#   'MHO',
#   'MIK',
#   'MINI',
#   'MKL',
#   'MKSI',
#   'MLHR',
#   'MLM',
#   'MLR',
#   'MMC',
#   'MMI',
#   'MMM',
#   'MMP',
#   'MMS',
#   'MMSI',
#   'MNK',
#   'MNRO',
#   'MO',
#   'MOBL',
#   'MOD',
#   'MOFG',
#   'MOH',
#   'MORN',
#   'MOS',
#   'MOV',
#   'MPB',
#   'MPC',
#   'MRC',
#   'MRCY',
#   'MRK',
#   'MS',
#   'MSA',
#   'MSBI',
#   'MSCI',
#   'MSFT',
#   'MSI',
#   'MSM',
#   'MSTR',
#   'MTB',
#   'MTD',
#   'MTEM',
#   'MTH',
#   'MTN',
#   'MTOR',
#   'MTRN',
#   'MTRX',
#   'MTSC',
#   'MTX',
#   'MTZ',
#   'MUEL',
#   'MWA',
#   'MXIM',
#   'MYGN',
#   'MYL',
#   'MYOK',
#   'MYRG',
#   'NATI',
#   'NAV',
#   'NAVI',
#   'NBL',
#   'NBTB',
#   'NCMI',
#   'NCR',
#   'NDAQ',
#   'NDLS',
#   'NDSN',
#   'NEE',
#   'NEM',
#   'NEO',
#   'NEOG',
#   'NES',
#   'NEWR',
#   'NFBK',
#   'NFG',
#   'NFLX',
#   'NGHC',
#   'NGL',
#   'NGMC',
#   'NGVC',
#   'NHC',
#   'NI',
#   'NJR',
#   'NKE',
#   'NLS',
#   'NNI',
#   'NOC',
#   'NOV',
#   'NOW',
#   'NP',
#   'NPO',
#   'NRG',
#   'NRIM',
#   'NS',
#   'NSC',
#   'NSIT',
#   'NSP',
#   'NSRGY',
#   'NTAP',
#   'NTGR',
#   'NTNX',
#   'NTRA',
#   'NTRS',
#   'NUE',
#   'NUS',
#   'NUVA',
#   'NVDA',
#   'NVEE',
#   'NVR',
#   'NVRO',
#   'NVTA',
#   'NWHM',
#   'NWL',
#   'NWLI',
#   'NWPX',
#   'NWSA',
#   'NX',
#   'NYT',
#   'O',
#   'OAS',
#   'OC',
#   'OCN',
#   'OCUL',
#   'ODFL',
#   'ODP',
#   'OGE',
#   'OGS',
#   'OI',
#   'OII',
#   'OIS',
#   'OKE',
#   'OKTA',
#   'OLLI',
#   'OLN',
#   ...],
#  '2020-01': ['A',
#   'AAL',
#   'AAN',
#   'AAP',
#   'AAWW',
#   'ABBV',
#   'ABC',
#   'ABG',
#   'ABM',
#   'ABMD',
#   'ABT',
#   'ACBI',
#   'ACC',
#   'ACCO',
#   'ACHC',
#   'ACIA',
#   'ACIW',
#   'ACN',
#   'ACU',
#   'ADBE',
#   'ADDDF',
#   'ADI',
#   'ADM',
#   'ADP',
#   'ADS',
#   'ADSK',
#   'ADSW',
#   'ADT',
#   'ADUS',
#   'ADVM',
#   'AEE',
#   'AEO',
#   'AEP',
#   'AES',
#   'AEYE',
#   'AFI',
#   'AFL',
#   'AGCO',
#   'AGIO',
#   'AGR',
#   'AGYS',
#   'AIMC',
#   'AIMT',
#   'AIN',
#   'AIR',
#   'AIT',
#   'AIZ',
#   'AJRD',
#   'AKAM',
#   'ALB',
#   'ALG',
#   'ALGN',
#   'ALGT',
#   'ALL',
#   'ALLE',
#   'ALLY',
#   'ALRM',
#   'ALRS',
#   'ALSN',
#   'ALTR',
#   'ALXN',
#   'AMAG',
#   'AMAT',
#   'AMBK',
#   'AMD',
#   'AME',
#   'AMED',
#   'AMGN',
#   'AMH',
#   'AMNB',
#   'AMP',
#   'AMRC',
#   'AMRS',
#   'AMSF',
#   'AMT',
#   'AMTD',
#   'AMWD',
#   'AN',
#   'ANAB',
#   'ANAT',
#   'ANDE',
#   'ANET',
#   'ANF',
#   'ANGO',
#   'ANIK',
#   'ANMP',
#   'ANSS',
#   'ANTM',
#   'AON',
#   'APD',
#   'APDN',
#   'APO',
#   'APPF',
#   'APPN',
#   'APRN',
#   'AQMS',
#   'ARA',
#   'ARAY',
#   'ARC',
#   'ARCB',
#   'ARLP',
#   'ARMK',
#   'AROC',
#   'ARW',
#   'ASB',
#   'ASH',
#   'ASNA',
#   'ASUR',
#   'ATEN',
#   'ATGE',
#   'ATKR',
#   'ATNI',
#   'ATNX',
#   'ATO',
#   'ATRA',
#   'ATRO',
#   'ATUS',
#   'AVA',
#   'AVAV',
#   'AVB',
#   'AVGO',
#   'AVID',
#   'AVY',
#   'AWI',
#   'AWK',
#   'AWR',
#   'AWRE',
#   'AXDX',
#   'AXE',
#   'AXL',
#   'AXP',
#   'AXTA',
#   'AYI',
#   'AYX',
#   'AZO',
#   'AZPN',
#   'B',
#   'BA',
#   'BABA',
#   'BAC',
#   'BAH',
#   'BAND',
#   'BANF',
#   'BAX',
#   'BBBY',
#   'BBW',
#   'BBY',
#   'BC',
#   'BCC',
#   'BCO',
#   'BCOV',
#   'BCPC',
#   'BDC',
#   'BEAT',
#   'BECN',
#   'BERK',
#   'BERY',
#   'BFAM',
#   'BGCP',
#   'BGFV',
#   'BGS',
#   'BGSF',
#   'BH',
#   'BHB',
#   'BHE',
#   'BHF',
#   'BIG',
#   'BIIB',
#   'BJRI',
#   'BKD',
#   'BKE',
#   'BKH',
#   'BKI',
#   'BKU',
#   'BL',
#   'BLD',
#   'BLDR',
#   'BLK',
#   'BLKB',
#   'BLL',
#   'BLMN',
#   'BLUE',
#   'BMI',
#   'BMY',
#   'BNED',
#   'BNFT',
#   'BOH',
#   'BOKF',
#   'BOOT',
#   'BOX',
#   'BPMC',
#   'BPOP',
#   'BRC',
#   'BREW',
#   'BRKL',
#   'BRKR',
#   'BRKS',
#   'BRO',
#   'BSET',
#   'BSX',
#   'BV',
#   'BW',
#   'BWA',
#   'BWXT',
#   'BXP',
#   'BXS',
#   'BY',
#   'BYD',
#   'BZH',
#   'C',
#   'CAC',
#   'CACC',
#   'CACI',
#   'CADE',
#   'CAG',
#   'CAH',
#   'CAKE',
#   'CAL',
#   'CALB',
#   'CAMP',
#   'CAPC',
#   'CAR',
#   'CARG',
#   'CARS',
#   'CASY',
#   'CAT',
#   'CATO',
#   'CB',
#   'CBOE',
#   'CBRE',
#   'CBRL',
#   'CBSH',
#   'CBT',
#   'CBU',
#   'CBZ',
#   'CC',
#   'CCBG',
#   'CCC',
#   'CCF',
#   'CCI',
#   'CCL',
#   'CCLP',
#   'CCNE',
#   'CCO',
#   'CCOI',
#   'CCRN',
#   'CCS',
#   'CDK',
#   'CDNA',
#   'CDNS',
#   'CDXS',
#   'CE',
#   'CECE',
#   'CEMI',
#   'CENT',
#   'CERN',
#   'CEVA',
#   'CF',
#   'CFFN',
#   'CFOK',
#   'CG',
#   'CGIX',
#   'CGNX',
#   'CHCI',
#   'CHD',
#   'CHDN',
#   'CHEF',
#   'CHGG',
#   'CHH',
#   'CHRS',
#   'CHRW',
#   'CHS',
#   'CHSCO',
#   'CHUY',
#   'CI',
#   'CIA',
#   'CICN',
#   'CIEN',
#   'CIR',
#   'CL',
#   'CLAR',
#   'CLDR',
#   'CLFD',
#   'CLGX',
#   'CLH',
#   'CLR',
#   'CLUB',
#   'CLW',
#   'CLX',
#   'CMA',
#   'CMC',
#   'CMCO',
#   'CMCSA',
#   'CMD',
#   'CME',
#   'CMG',
#   'CMI',
#   'CMLS',
#   'CMP',
#   'CMTL',
#   'CMTV',
#   'CNBKA',
#   'CNC',
#   'CNDT',
#   'CNMD',
#   'CNOB',
#   'CNP',
#   'CNR',
#   'CNSL',
#   'COF',
#   'COHN',
#   'COHR',
#   'COKE',
#   'COLB',
#   'COLM',
#   'CONN',
#   'COO',
#   'COP',
#   'CORT',
#   'COST',
#   'COTY',
#   'CPB',
#   'CPK',
#   'CPN',
#   'CPRT',
#   'CR',
#   'CRBP',
#   'CREE',
#   'CRHCF',
#   'CRI',
#   'CRLKP',
#   'CRMT',
#   'CRMZ',
#   'CROX',
#   'CRS',
#   'CRSP',
#   'CRUS',
#   'CRVS',
#   'CRY',
#   'CSCO',
#   'CSGP',
#   'CSII',
#   'CSL',
#   'CSLT',
#   'CSOD',
#   'CSU',
#   'CSV',
#   'CSVI',
#   'CSX',
#   'CTAS',
#   'CTB',
#   'CTBI',
#   'CTEK',
#   'CTHR',
#   'CTL',
#   'CTLT',
#   'CTMX',
#   'CTRN',
#   'CTSH',
#   'CUB',
#   'CUBI',
#   'CULP',
#   'CUTR',
#   'CVCY',
#   'CVEO',
#   'CVS',
#   'CVT',
#   'CVTI',
#   'CVX',
#   'CW',
#   'CWH',
#   'CWST',
#   'CWT',
#   'CXW',
#   'CYH',
#   'CZBS',
#   'CZR',
#   'D',
#   'DAKT',
#   'DAN',
#   'DAR',
#   'DBD',
#   'DCI',
#   'DCO',
#   'DDS',
#   'DE',
#   'DELL',
#   'DENN',
#   'DFIN',
#   'DFS',
#   'DG',
#   'DGX',
#   'DHI',
#   'DHX',
#   'DIN',
#   'DIS',
#   'DISCA',
#   'DISH',
#   'DLTR',
#   'DLX',
#   'DNKN',
#   'DOOR',
#   'DORM',
#   'DOV',
#   'DOW',
#   'DPSGY',
#   'DPZ',
#   'DRAD',
#   'DRI',
#   'DS',
#   'DTE',
#   'DUK',
#   'DVA',
#   'DVCR',
#   'DVLN',
#   'DXC',
#   'DXCM',
#   'DXLG',
#   'DXPE',
#   'DXYN',
#   'DYNT',
#   'EA',
#   'EAT',
#   'EBAY',
#   'EBIX',
#   'EBS',
#   'EBTC',
#   'ECHO',
#   'ECL',
#   'ECOL',
#   'EE',
#   'EEX',
#   'EGBN',
#   'EGHT',
#   'EGOV',
#   'EHC',
#   'EHTH',
#   'EIGI',
#   'EIX',
#   'EL',
#   'ELS',
#   'EME',
#   'EML',
#   'EMR',
#   'ENAB',
#   'ENBL',
#   'ENG',
#   'ENLC',
#   'ENPH',
#   'ENR',
#   'ENS',
#   'ENT',
#   'ENTG',
#   'ENVA',
#   'EPAM',
#   'EPAY',
#   'EPC',
#   'EQIX',
#   'EQR',
#   'ESBK',
#   'ESS',
#   'ETFC',
#   'ETH',
#   'ETM',
#   'ETN',
#   'ETR',
#   'ETSY',
#   'EV',
#   'EVBN',
#   'EVC',
#   'EVH',
#   'EW',
#   'EWBC',
#   'EXAS',
#   'EXC',
#   'EXEL',
#   'EXPO',
#   'EXPR',
#   'EXR',
#   'EXTR',
#   'EYE',
#   'F',
#   'FAST',
#   'FB',
#   'FBAK',
#   'FBC',
#   'FC',
#   'FCBC',
#   'FCF',
#   'FCFS',
#   'FCN',
#   'FCOB',
#   'FCX',
#   'FDX',
#   'FELE',
#   'FET',
#   'FFBC',
#   'FGBI',
#   'FGEN',
#   'FHB',
#   'FIBK',
#   'FISV',
#   'FIT',
#   'FIVE',
#   'FIVN',
#   'FIZZ',
#   'FL',
#   'FLDM',
#   'FLIR',
#   'FLO',
#   'FLOW',
#   'FLR',
#   'FLS',
#   'FLXN',
#   'FLXS',
#   'FMBI',
#   'FMBM',
#   'FMC',
#   'FMCB',
#   'FMCC',
#   'FMNB',
#   'FNB',
#   'FND',
#   'FNF',
#   'FNKO',
#   'FNWB',
#   'FOE',
#   'FOLD',
#   'FORM',
#   'FORR',
#   'FOSL',
#   'FPCG',
#   'FRAN',
#   'FRC',
#   'FRGI',
#   'FRME',
#   'FSLR',
#   'FSS',
#   'FSTR',
#   'FTLF',
#   'FUL',
#   'FULT',
#   'FUNC',
#   'FVE',
#   'FWRD',
#   'GABC',
#   'GATX',
#   'GCI',
#   'GCO',
#   'GCP',
#   'GD',
#   'GDDY',
#   'GDEN',
#   'GDOT',
#   'GE',
#   'GEF',
#   'GEN',
#   'GEO',
#   'GES',
#   'GFNL',
#   'GGG',
#   'GHC',
#   'GIB',
#   'GIFOF',
#   'GIII',
#   'GILD',
#   'GIS',
#   'GLDD',
#   'GLP',
#   'GLUU',
#   'GLW',
#   'GM',
#   'GME',
#   'GMED',
#   'GNC',
#   'GNTX',
#   'GNW',
#   'GOGO',
#   'GOOGL',
#   'GPC',
#   'GPI',
#   'GPK',
#   'GPN',
#   'GPRE',
#   'GPRO',
#   'GPS',
#   'GPX',
#   'GRA',
#   'GRMN',
#   'GRRB',
#   'GRUB',
#   'GS',
#   'GSBC',
#   'GT',
#   'GTHX',
#   'GTT',
#   'GVA',
#   'GWB',
#   'GWRE',
#   'GWW',
#   'H',
#   'HAE',
#   'HAL',
#   'HAS',
#   'HBCP',
#   'HBI',
#   'HBMD',
#   'HBNC',
#   'HBP',
#   'HCA',
#   'HCCI',
#   'HCI',
#   'HCSG',
#   'HD',
#   'HDS',
#   'HEAR',
#   'HEES',
#   'HEI',
#   'HELE',
#   'HES',
#   'HGV',
#   'HHS',
#   'HIBB',
#   'HIL',
#   'HLI',
#   'HLT',
#   'HMHC',
#   'HMN',
#   'HMST',
#   'HMSY',
#   'HNFSA',
#   'HNGR',
#   'HOG',
#   'HOLX',
#   'HON',
#   'HPE',
#   'HPP',
#   'HQY',
#   'HR',
#   'HRB',
#   'HRTX',
#   'HRZN',
#   'HSC',
#   'HSTM',
#   'HSY',
#   'HTGM',
#   'HTH',
#   'HTLD',
#   'HTLF',
#   'HTZ',
#   'HUBB',
#   'HUBG',
#   'HUBS',
#   'HUM',
#   'HURN',
#   'HVT',
#   'HWKN',
#   'HXL',
#   'HY',
#   'HZN',
#   'IART',
#   'IBKC',
#   'IBM',
#   'IBP',
#   'ICAD',
#   'ICE',
#   'ICFI',
#   'ICPT',
#   'ICUI',
#   'IEP',
#   'IESC',
#   'IEX',
#   'IHG',
#   'III',
#   'IIVI',
#   'IMAX',
#   'IMKTA',
#   'IMMU',
#   'INCY',
#   'INDB',
#   'INFN',
#   'INGR',
#   'INO',
#   'INOV',
#   'INSM',
#   'INT',
#   'INTC',
#   'INTL',
#   'INTU',
#   'INVE',
#   'INVH',
#   'INWK',
#   'IP',
#   'IPHI',
#   'IR',
#   'IRBT',
#   'IRM',
#   'IRWD',
#   'ISBC',
#   'ISDR',
#   'ISRG',
#   'IT',
#   'ITEX',
#   'ITI',
#   'ITIC',
#   'ITRI',
#   'IVC',
#   'IVZ',
#   'IZEA',
#   'JACK',
#   'JAX',
#   'JBHT',
#   'JBLU',
#   'JBSS',
#   'JCI',
#   'JJSF',
#   'JKHY',
#   'JNJ',
#   'JNPR',
#   'JPM',
#   'JWN',
#   'K',
#   'KAR',
#   'KBAL',
#   'KBH',
#   'KBR',
#   'KCLI',
#   'KDP',
#   'KEX',
#   'KEYS',
#   'KFRC',
#   'KGHI',
#   'KHC',
#   'KIM',
#   'KIRK',
#   'KMB',
#   'KMI',
#   'KMPR',
#   'KMT',
#   'KMX',
#   'KN',
#   'KNX',
#   'KO',
#   'KR',
#   'KRA',
#   'KSS',
#   'KSU',
#   'KTOS',
#   'KTYB',
#   'KVHI',
#   'L',
#   'LAD',
#   'LAMR',
#   'LARK',
#   'LAUR',
#   'LAWS',
#   'LB',
#   'LC',
#   'LDOS',
#   'LE',
#   'LECO',
#   'LEE',
#   'LEG',
#   'LEN',
#   'LEU',
#   'LGIH',
#   'LHCG',
#   'LHX',
#   'LIND',
#   'LKQ',
#   'LL',
#   'LMT',
#   'LNG',
#   'LNN',
#   'LNT',
#   'LOCMQ',
#   'LOCO',
#   'LOW',
#   'LPLA',
#   'LPSN',
#   'LQDT',
#   'LRCX',
#   'LRN',
#   'LSI',
#   'LSTR',
#   'LUNA',
#   'LUV',
#   'LVS',
#   'LW',
#   'LYTS',
#   'LZB',
#   'M',
#   'MA',
#   'MAC',
#   'MAN',
#   'MANH',
#   'MANT',
#   'MAR',
#   'MAS',
#   'MASI',
#   'MAT',
#   'MCHP',
#   'MCHX',
#   'MCK',
#   'MCRB',
#   'MCS',
#   'MD',
#   'MDB',
#   'MDP',
#   'MDRX',
#   'MDT',
#   'MDXG',
#   'MED',
#   'MEDP',
#   'MEI',
#   'MET',
#   'MFBP',
#   'MG',
#   'MGLN',
#   'MGM',
#   'MGRC',
#   'MHGU',
#   'MHH',
#   'MHK',
#   'MIK',
#   'MINI',
#   'MITK',
#   'MKL',
#   'MKSI',
#   'MLHR',
#   'MLM',
#   'MMC',
#   'MMI',
#   'MMM',
#   'MMP',
#   'MMS',
#   'MMSI',
#   'MNK',
#   'MNRO',
#   'MNTA',
#   'MO',
#   'MOBL',
#   'MOD',
#   'MOFG',
#   'MOH',
#   'MORN',
#   'MOS',
#   'MOV',
#   'MPC',
#   'MRCY',
#   'MRK',
#   'MRTN',
#   'MS',
#   'MSA',
#   'MSBI',
#   'MSCI',
#   'MSFT',
#   'MSI',
#   'MSM',
#   'MSTR',
#   'MTB',
#   'MTD',
#   'MTH',
#   'MTN',
#   'MTOR',
#   'MTRN',
#   'MTSC',
#   'MTX',
#   'MTZ',
#   'MUEL',
#   'MUR',
#   'MWA',
#   'MXIM',
#   'MXL',
#   'MYGN',
#   'MYL',
#   'MYRG',
#   'NATI',
#   'NAV',
#   'NAVI',
#   'NBL',
#   'NBN',
#   'NBTB',
#   'NCR',
#   'NCSM',
#   'NDAQ',
#   'NDLS',
#   'NDSN',
#   'NEE',
#   'NEO',
#   'NEOG',
#   'NEWR',
#   'NEWT',
#   'NFBK',
#   'NFG',
#   'NFLX',
#   'NGHC',
#   'NGL',
#   'NGVC',
#   'NGVT',
#   'NHC',
#   'NI',
#   'NJR',
#   'NKE',
#   'NLS',
#   'NNI',
#   'NOC',
#   'NOV',
#   'NOVT',
#   'NOW',
#   'NP',
#   'NRG',
#   'NSC',
#   'NSIT',
#   'NSP',
#   'NSRGY',
#   'NTAP',
#   'NTGR',
#   'NTNX',
#   'NTRA',
#   'NTRS',
#   'NURO',
#   'NVDA',
#   'NVEE',
#   'NVR',
#   'NVTA',
#   'NWL',
#   'NWPX',
#   'NWSA',
#   'NX',
#   'NYT',
#   'O',
#   'OC',
#   'OCN',
#   'OCUL',
#   'ODC',
#   'ODFL',
#   'ODP',
#   'OGE',
#   'OGS',
#   'OI',
#   'OII',
#   'OIS',
#   'OKE',
#   'OKTA',
#   'OLLI',
#   'OLN',
#   'OMCL',
#   'OMF',
#   'OMI',
#   'OPY',
#   'ORBC',
#   'ORCL',
#   'ORLY',
#   'ORN',
#   'OSIS',
#   'OTEL',
#   'OTTR',
#   'OUT',
#   'OXBC',
#   'OXY',
#   'PAA',
#   'PAG',
#   'PANW',
#   'PAOS',
#   'PARR',
#   'PATK',
#   'PAYX',
#   'PB',
#   'PBCT',
#   'PBF',
#   'PBHC',
#   'PBI',
#   'PBPB',
#   'PBYI',
#   'PCAR',
#   'PCG',
#   'PDCO',
#   'PE',
#   'PEBK',
#   'PEBO',
#   'PEGA',
#   'PEIX',
#   'PEP',
#   'PFE',
#   'PFG',
#   'PFGC',
#   'PFNX',
#   'PFPT',
#   'PFSI',
#   'PFSW',
#   'PG',
#   'PGC',
#   'PGR',
#   'PH',
#   'PHM',
#   'PI',
#   'PII',
#   'PINC',
#   'PKG',
#   ...]}

# %%
regression_df = pd.read_csv('VAR_predicted_returns_new.csv')
regression_df
# Out:
#      Ticker    2019-08    2019-09    2019-10    2019-11    2019-12    2020-01
# 0         A   3.633120   1.941639  -0.989184   5.475272  -2.035121   1.343574
# 1        AA  14.259083  -1.763753   6.228646   6.482264  -0.420609   0.550378
# 2       AAL  16.110883   1.934161  -2.993551 -31.895237   7.919258  10.497010
# 3       AAN   1.698000   6.734586   1.934730  36.191153 -18.230439  -3.851623
# 4       AAP  -9.364314  -6.389783 -19.404428  38.331948   7.888393  12.771770
# ...     ...        ...        ...        ...        ...        ...        ...
# 1320   ZGNX   2.006088 -15.245307  10.392096  21.964742   1.974457   0.896183
# 1321   ZION   0.560555  -7.599444  -4.146234   2.135531   8.367711   5.627621
# 1322   ZNGA  -7.435770  13.148979  10.374427   2.200228   2.926059  -8.774518
# 1323    ZTS   2.940268   2.485700   4.705163   4.650009   5.501232   0.829577
# 1324   ZUMZ  -4.981741  -6.881586 -12.681273 -11.792342  -6.562762  -2.807756
#
# [1325 rows x 7 columns]

# %%
def volatility(stock_returns, ticker, end):
    df = stock_returns[ticker]
    returns = df[df.Date <= end]['Monthly_return']
    volatility = returns.std()
    return volatility

# %%
def mean_return(stock_returns, ticker, end):
    df = stock_returns[ticker]
    returns = df[df.Date <= end]['Monthly_return']
    mean = returns.mean()
    return mean

# %%
def sharpe(stock_returns, ticker, date, predicted):
    vol = volatility(stock_returns, ticker, date)
    mean = mean_return(stock_returns, ticker, date)
    #sharpe = predicted / vol
    sharpe = mean / vol
    return sharpe

# %%
def previous_month(date):
    year = int(date.split('-')[0])
    month = int(date.split('-')[1])
    if month > 1:
        month = month - 1
    else:
        month = 12
        year = year - 1
    return str(year) + '-' + str(month).zfill(2)

# %%
def next_month(date):
    year = int(date.split('-')[0])
    month = int(date.split('-')[1])
    if month < 12:
        month = month + 1
    else:
        month = 1
        year = year + 1
    return str(year) + '-' + str(month).zfill(2)

# %%
def top(classification, regression, dow30, date, num, last):
    result = []
    if last == False:
        positives = list(classification.loc[(classification[date] == 1) | (classification[next_month(date)] == 1)]['Ticker'])
    else:
        positives = list(classification.loc[classification[date] == 1]['Ticker'])
    makesense_df = regression[['Ticker', date]].sort_values(date, ascending=False)
    makesense_df = makesense_df[(makesense_df[date] <= 20) & (makesense_df[date] >= 2)]
    makesense_df['sharpe'] = makesense_df.apply(lambda x: sharpe(stock_returns, x['Ticker'], previous_month(date), x[date]), axis=1)
    makesense = list(makesense_df.sort_values('sharpe', ascending=False)['Ticker'])
    #makesense = list(makesense_df.sort_values(date, ascending=False)['Ticker'])
    count = 1
    i = 0
    while count <= num:
        if makesense[i] in positives and makesense[i] not in dow30:
            result.append(makesense[i])
            count += 1
        i = i + 1
    return result

# %%
portfolio_stocks_new_by_month = {}
for i in range(len(months)):
    if i != len(months) - 1:
        portfolio_stocks_new_by_month[months[i]] = top(classification_df, regression_df, dow, months[i], 10, False)
    else:
        portfolio_stocks_new_by_month[months[i]] = top(classification_df, regression_df, dow, months[i], 10, True)
portfolio_stocks_new_by_month
# Out:
# {'2019-08': ['HEI',
#   'PLNT',
#   'MDB',
#   'CABO',
#   'INTU',
#   'MA',
#   'OKTA',
#   'RCM',
#   'PGR',
#   'CTAS'],
#  '2019-09': ['HEI',
#   'CWST',
#   'BAND',
#   'WM',
#   'CABO',
#   'MDB',
#   'PLNT',
#   'MA',
#   'TDY',
#   'REXR'],
#  '2019-10': ['CWST',
#   'NEE',
#   'WCN',
#   'WM',
#   'AYX',
#   'TDY',
#   'CABO',
#   'NOVT',
#   'REXR',
#   'MA'],
#  '2019-11': ['CWST',
#   'NEE',
#   'RSG',
#   'WCN',
#   'SUI',
#   'CABO',
#   'TDY',
#   'WM',
#   'REXR',
#   'ELS'],
#  '2019-12': ['CWST',
#   'WCN',
#   'TDY',
#   'NOVT',
#   'AYX',
#   'REXR',
#   'ELS',
#   'APPF',
#   'MSA',
#   'PLNT'],
#  '2020-01': ['WCN',
#   'TDY',
#   'MA',
#   'MSA',
#   'SUI',
#   'ADBE',
#   'AMD',
#   'SPGI',
#   'CDNS',
#   'OKTA']}

# %%
def get_returns(tickers, date, rf, returns):
    df = rf[rf['Date'] < date].set_index('Date')['Risk Free Return']
    for ticker in tickers:
        temp = returns[ticker]
        risky = temp[temp['Date'] < date].set_index('Date')['Monthly_return']
        df = pd.concat([df, risky], axis=1)
    names = copy.deepcopy(tickers)
    names.insert(0, 'RF')
    df.columns = names
    return df

# %%
def get_expectations(tickers, date, regression):
    ind=[regression.index[regression['Ticker']==i].tolist() for i in tickers]
    flat_ind=[item for sublist in ind for item in sublist]
    expectations = regression.reindex(flat_ind)[['Ticker', date]].set_index('Ticker').rename_axis([None]).squeeze()
    return expectations

# %%
# CAPM tangency portfolio weight optimization
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt.base_optimizer import BaseConvexOptimizer
from pypfopt import objective_functions
def portfolio_weights_optimization(tickers, date, rf, returns):
    returns_df = get_returns(tickers, date, rf, returns)
    riskfree_return = returns_df['RF'] / 100
    risky_returns = returns_df.iloc[:, 1:] / 100
    excess_return = risky_returns.subtract(riskfree_return, axis=0)
    mu = excess_return.mean()
    sigma = excess_return.cov()
    ef = EfficientFrontier(mu, sigma)
    #ef.add_objective(objective_functions.L2_reg, gamma=2)
    w = ef.max_sharpe()
    return ef.clean_weights()

# %%
# get the portfolio after weight optimization
def portfolio_after_optimization(weights):
    result = {}
    for ticker in weights.keys():
        weight = weights[ticker]
        if weight >= 0.01:
            result[ticker] = weight
    return result

# %%
import copy
def portfolio_by_month(stocks_by_month, returns, months, rf, classification, regression):
    result = {}
    result_weights = {}
    ages = {}
    initial = stocks_by_month[months[0]]
    weights = portfolio_weights_optimization(initial, months[0], rf, returns)
    new_list = portfolio_after_optimization(weights)
    initial = list(new_list.keys())
    result[months[0]] = initial
    result_weights[months[0]] = new_list
    for stock in initial:
        ages[stock] = 0
    result[months[0]] = initial
    for i in range(1, len(months)):
        temp = copy.deepcopy(initial)
        month = months[i]
        for stock in temp:
            ages[stock] += 1
        for stock in temp:
            if int(classification[classification['Ticker'] == stock][month]) == 0 and float(regression[regression['Ticker'] == stock][month]) < 0:
                temp.remove(stock)
        for stock in temp:
            if ages[stock] >= 2:
                month_pre = previous_month(month)
                month_prepre = previous_month(month_pre)
                return_df = returns[stock]
                if float(return_df.loc[(return_df['Date'] == month_pre)]['Monthly_return']) < 0 and float(return_df.loc[return_df['Date'] == month_prepre]['Monthly_return']) < 0:
                    temp.remove(stock)
        potential_new = stocks_by_month[month]
        for stock in potential_new:
            if stock not in temp:
                temp.append(stock)
                ages[stock] = 0
        weights = portfolio_weights_optimization(temp, month, rf, returns)
        new_list = portfolio_after_optimization(weights)
        temp = list(new_list.keys())
        result[month] = temp
        result_weights[month] = new_list
        initial = temp
    return result, result_weights

# %%
portfolio_tracking = portfolio_by_month(portfolio_stocks_new_by_month, stock_returns, months, risk_free, classification_df, regression_df)
portfolio_tracking
# Out:
# ({'2019-08': ['HEI', 'PLNT', 'MDB', 'OKTA', 'RCM'],
#   '2019-09': ['PLNT', 'MDB', 'OKTA', 'CWST'],
#   '2019-10': ['MDB', 'CWST', 'NEE', 'AYX', 'NOVT'],
#   '2019-11': ['MDB', 'CWST', 'NEE', 'AYX', 'NOVT'],
#   '2019-12': ['MDB', 'CWST', 'NEE', 'AYX', 'NOVT'],
#   '2020-01': ['MDB', 'CWST', 'NEE', 'NOVT', 'AMD', 'OKTA']},
#  {'2019-08': {'HEI': 0.10923,
#    'PLNT': 0.38476,
#    'MDB': 0.23572,
#    'OKTA': 0.15562,
#    'RCM': 0.11468},
#   '2019-09': {'PLNT': 0.06842,
#    'MDB': 0.23644,
#    'OKTA': 0.15051,
#    'CWST': 0.54463},
#   '2019-10': {'MDB': 0.14087,
#    'CWST': 0.41895,
#    'NEE': 0.21682,
#    'AYX': 0.0856,
#    'NOVT': 0.13775},
#   '2019-11': {'MDB': 0.16081,
#    'CWST': 0.40492,
#    'NEE': 0.23126,
#    'AYX': 0.02943,
#    'NOVT': 0.17359},
#   '2019-12': {'MDB': 0.16597,
#    'CWST': 0.41004,
#    'NEE': 0.21186,
#    'AYX': 0.04358,
#    'NOVT': 0.16857},
#   '2020-01': {'MDB': 0.12969,
#    'CWST': 0.37399,
#    'NEE': 0.29655,
#    'NOVT': 0.11646,
#    'AMD': 0.02789,
#    'OKTA': 0.04942}})

# %%
def get_actual_returns(tracking, returns):
    result = {}
    for date in tracking.keys():
        tickers = tracking[date]
        temp = {}
        for ticker in tickers:
            df = returns[ticker]
            actual_return = float(df[df['Date'] == date]['Monthly_return'])
            temp[ticker] = actual_return
        result[date] = temp
    return result    
actual_returns = get_actual_returns(portfolio_tracking[0], stock_returns)
actual_returns
# Out:
# {'2019-08': {'HEI': 5.791594280212031,
#   'PLNT': -10.233921531884585,
#   'MDB': 6.346876316446104,
#   'OKTA': -3.309639815373666,
#   'RCM': -7.313196199312166},
#  '2019-09': {'PLNT': -18.042772367005316,
#   'MDB': -20.89816473762015,
#   'OKTA': -22.166008628875364,
#   'CWST': -5.626376644595643},
#  '2019-10': {'MDB': 6.050791071556928,
#   'CWST': 1.5137437043945434,
#   'NEE': 2.296228276153633,
#   'AYX': -14.828260504443382,
#   'NOVT': 8.969654578514243},
#  '2019-11': {'MDB': 16.38099777340143,
#   'CWST': 7.157602479842009,
#   'NEE': -1.371655794582738,
#   'AYX': 24.07650139813866,
#   'NOVT': 4.6378406646628845},
#  '2019-12': {'MDB': -11.492936576077485,
#   'CWST': -1.4557917330420778,
#   'NEE': 3.566842954378391,
#   'AYX': -11.855896440762761,
#   'NOVT': -5.086926216189591},
#  '2020-01': {'MDB': 27.216770685595087,
#   'CWST': 12.035631245810707,
#   'NEE': 11.467636039627529,
#   'NOVT': 6.399814423868588,
#   'AMD': 6.3672004580964,
#   'OKTA': 15.229261746155887}}

# %%
stock_df2 = pd.read_csv('yfinanceAPI_monthly3.csv')
stock_df2 = stock_df2[['ticker', 'date2', 'Adj Close']]
stock_df2.columns = ['Ticker', 'Date', 'Price']
stock_df2
# Out:
#        Ticker     Date      Price
# 0           A  2016-01  36.028095
# 1           A  2016-02  35.741016
# 2           A  2016-03  38.133320
# 3           A  2016-04  39.270550
# 4           A  2016-05  44.040211
# ...       ...      ...        ...
# 138419   ZVLO  2019-09   0.050000
# 138420   ZVLO  2019-10   0.050000
# 138421   ZVLO  2019-11   0.050000
# 138422   ZVLO  2019-12   0.050000
# 138423   ZVLO  2020-01   0.060000
#
# [138424 rows x 3 columns]

# %%
def get_price(prices, ticker, date):
    return float(prices[(prices['Ticker'] == ticker) & (prices['Date'] == date)]['Price'])

# %%
def HPR(stock_tracking, weight_tracking, prices):
    portfolio_value = 1000000
    for date in weight_tracking.keys():
        stock_value_start = 0
        stock_value_end = 0
        weights = weight_tracking[date]
        tickers = stock_tracking[date]
        for ticker in tickers:
            weight = weights[ticker]
            price_start = get_price(prices, ticker, previous_month(date))
            price_end = get_price(prices, ticker, date)
            num = int(portfolio_value * weight / price_start)
            value_start = num * price_start
            value_end = num * price_end
            stock_value_start += value_start
            stock_value_end += value_end
        cash = portfolio_value - stock_value_start
        new_value = stock_value_end + cash
        portfolio_value = new_value
    HPR = portfolio_value / 1000000 - 1
    print(HPR)
HPR(portfolio_tracking[0], portfolio_tracking[1], stock_df2)
# Out:
# 0.009352390708923242
